# %% [markdown]
# <a href="https://colab.research.google.com/github/sainvo/Project_Sentiment_analyser/blob/master/NLP_project_sentiment_detector_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Milestone II
#
# Project groups will analyze this data to 1) identify inconsistencies and challenges in annotation as well as to 2) identify groups of synonymous aspects.
#
# The data can be analysed manually, or semi-automatically by calculating and analysing basic data statistics (e.g. label frequencies, aspect frequencies etc.).

# %%
# !wget -nc https://raw.githubusercontent.com/sainvo/Project_Sentiment_analyser/master/combined-sentiment-judgments.tsv
# Out:
# File ‘combined-sentiment-judgments.tsv’ already there; not retrieving.

# %%
import csv
from pprint import pprint

data = []

with open("combined-sentiment-judgments.tsv", encoding= 'utf-8') as tsv:
    tsvreader = csv.reader(tsv, delimiter= '\t')   
    for line in tsvreader:
        # 0:id, 1=judgement, 2=aspects, 3=left, 4= target, 5=right
        #print (line)
        judg = line[1].split(",")
        #print(judg)
     #
        data.append({"id":line[0], "judgement":judg, "aspects":line[2].split(','), "left context":line[3], "target":line[4], "right context":line[5]})
#print(evals[:5])
print()
print(len(data))
pprint(data[:3])
       
counts = []
for item in data:
    #print(eval)
    #count = {"positive":0, "neutral":0, "negative":0, "mixed":0, "unclear":0, "total" :0}
    count = {"positive":0, "neutral":0, "negative":0, "mixed":0, "unclear":0}
    for i in item.get('judgement'):
        #print(i) 
        #count["total"] += 1s
        if (i == "mixed"):
            count["mixed"] = count.get("mixed") +1
        elif (i == "unclear"):
            count["unclear"] = count.get("unclear") +1
        elif (i == "positive"):
             count["positive"] = count.get("positive") +1
        elif(i == "neutral"):
            count["neutral"] = count.get("neutral") + 1
        elif(i == "negative"):
             count["negative"] = count.get("negative") +1
    counts.append(count)
pprint(counts[:10])
# Out:
# 980
# [{'aspects': ['status'],
#   'id': 'ajoneuvot00692',
#   'judgement': ['positive', 'neutral'],
#   'left context': 'Tämä . BMW provosoi tarpeettomiin ohituksiin . '
#                   'Liikennevaloissa lähtiessäkin on usein yhden hengen '
#                   'kiihdytyskisat pystyssä . ',
#   'right context': ' ratissa ei tarvitse katsella tätä , vaikka ajotyyli ja '
#                    'nopeus on samoja . Onko tämä sitä kateutta ?',
#   'target': 'Fordin'},
#  {'aspects': ['auto', 'merkki', 'ääni'],
#   'id': 'ajoneuvot00697',
#   'judgement': ['positive', 'positive', 'positive', 'positive'],
#   'left context': '',
#   'right context': ' on kyllä upeita . Hyväkuntoiset on vaan aikalailla viety '
#                    'käsistä . Aika paljon noita myös laitellaan , mutta '
#                    'hyvällä maulla mielestäni ( motorsport hengessä ) . Olen '
#                    'ollut parin + 250hp vaparin kyydissä . Suorakutonen laulaa '
#                    'nätisti 8000rpm .',
#   'target': 'Zetat'},
#  {'aspects': ['hinta', 'piirteet'],
#   'id': 'ajoneuvot01589',
#   'judgement': ['mixed', 'neutral', 'neutral'],
#   'left context': 'Tässä langassa lienee paras kysyä , mitä tulisi huomioida ',
#   'right context': ' hankinnassa , niitähän saa jo parilla tonnilla . Ainoat '
#                    'kriteerit : nahkasisusta , ilmastointi , sedan .',
#   'target': 'E39 : n'}]
# [{'mixed': 0, 'negative': 0, 'neutral': 1, 'positive': 1, 'unclear': 0},
#  {'mixed': 0, 'negative': 0, 'neutral': 0, 'positive': 4, 'unclear': 0},
#  {'mixed': 1, 'negative': 0, 'neutral': 2, 'positive': 0, 'unclear': 0},
#  {'mixed': 0, 'negative': 0, 'neutral': 1, 'positive': 3, 'unclear': 0},
#  {'mixed': 0, 'negative': 3, 'neutral': 0, 'positive': 0, 'unclear': 0},
#  {'mixed': 3, 'negative': 0, 'neutral': 0, 'positive': 0, 'unclear': 0},
#  {'mixed': 0, 'negative': 2, 'neutral': 0, 'positive': 0, 'unclear': 0},
#  {'mixed': 0, 'negative': 0, 'neutral': 0, 'positive': 4, 'unclear': 0},
#  {'mixed': 1, 'negative': 0, 'neutral': 0, 'positive': 3, 'unclear': 0},
#  {'mixed': 1, 'negative': 3, 'neutral': 0, 'positive': 0, 'unclear': 0}]

# %% [markdown]
# # Task II: analysis
# So, above we already counted the instances of each label per sentence in the data.
# Let's do some more analysis on the data before se use it

# %%
# Counting the judgement labels
from collections import Counter
import numpy as np

counts_tot = []
for count in counts:
    total = sum(count.values())
    counts_tot.append(total)

tot_counter = Counter()
tot_counter.update(counts_tot)

print("Distribution of label evals: ",tot_counter)
dict_tot = dict(tot_counter)
dict_keys = dict_tot.keys()
keys = np.array(list(dict_keys))
values = np.array(list(dict_tot.values()))
dict_copy = dict_tot
for key in dict_keys:
    dict_copy[key] = dict_copy[key]/980
print("Percentages: ", dict_copy)
pers = np.array(list(dict_copy.values()))
print("keys: ", keys, ", values: ", values, ", percentages", pers)
# Out:
# Distribution of label evals:  Counter({3: 346, 2: 293, 4: 195, 1: 109, 5: 37})
# Percentages:  {2: 0.29897959183673467, 4: 0.1989795918367347, 3: 0.35306122448979593, 5: 0.03775510204081633, 1: 0.11122448979591837}
# keys:  [2 4 3 5 1] , values:  [293 195 346  37 109] , percentages [0.29897959 0.19897959 0.35306122 0.0377551  0.11122449]

# %%
#statistics
average = np.average(keys)
print("normal average: ",average)
#weighted average
w_av = np.average(keys, weights=pers)
print("weighted average: ",w_av)
median = np.median(values)
av_val = np.average(values)
print("median: ", median, "average per label type: ",av_val)
# Out:
# normal average:  3.0
# weighted average:  2.7530612244897963
# median:  195.0 average per label type:  196.0

# %% [markdown]
# ## inconsistencies and challenges in annotation

# %% [markdown]
# From this distribution we can see that most of the sentences have been evaluated twice or more, only about 11 per cent of the sentences having just one label and about 4 percent having five evals.So, on average each sentence has about 2.7 labels.
#
# Based on this, I decided to use the majority labels as a deciding factor for train/dev/test division, meaning that if there is a label with 1.00 weight or more (definite majority label present), this would become the final label for this sentence in the training set. The sentences with label *unclear* or *mixed* go to test set, so we can see, if the model can relabel them to one of the three major classes. The sentences with more than one label shall be handled as follows:
#
# * if the sentence has a majority label with weight of >= 0.66, the majority label will be present in the dev set, otherwise it will be put into the test set.

# %% [markdown]
# ## Preprocessing the data and division to train/dev/test sets

# %%
# let's change the counts to percentages 
for count in counts:
    #print(count)
    total = sum(count.values())
    #print(total) ##check
    
    for item in count:
        #print(item)
        pros = count.get(item)/total
        #print(pros)
        count[item] = pros
    #print(count)
pprint(counts[:3])
# Out:
# [{'mixed': 0.0,
#   'negative': 0.0,
#   'neutral': 0.5,
#   'positive': 0.5,
#   'unclear': 0.0},
#  {'mixed': 0.0,
#   'negative': 0.0,
#   'neutral': 0.0,
#   'positive': 1.0,
#   'unclear': 0.0},
#  {'mixed': 0.3333333333333333,
#   'negative': 0.0,
#   'neutral': 0.6666666666666666,
#   'positive': 0.0,
#   'unclear': 0.0}]

# %%
judg_list = []

for count in counts:
    #print(count)
    max_key = max(count.items(), key = lambda x :x[1])
    keys = list(count.keys())
    values = list(count.values())
    #print(max_key)
    for value in values:
        if value == count.get(max_key): ## check for 50/50 and other evenly dispersed cases
            max_key = null
    if (max_key[1]== 1.0):
        final_eval = max_key[0]
        #print("Final label: ",final_eval)
        judg_list.append(final_eval)
    else:
        multi = []
        for key in keys:
            if count.get(key) > 0:
                multi.append([key,count.get(key)])
        judg_list.append(multi)
pprint(judg_list[:10])
print(len(judg_list))
# as seen below (result), now the judgements are either single string per sentence or an array
# Out:
# [[['positive', 0.5], ['neutral', 0.5]],
#  'positive',
#  [['neutral', 0.6666666666666666], ['mixed', 0.3333333333333333]],
#  [['positive', 0.75], ['neutral', 0.25]],
#  'negative',
#  'mixed',
#  'negative',
#  'positive',
#  [['positive', 0.75], ['mixed', 0.25]],
#  [['negative', 0.75], ['mixed', 0.25]]]
# 980

# %%
# Setting the single labels back to the data
for i in range(len(data)):
    datapoint= data[i]
    if len(judg_list[i]) ==1: # one judg, type=str
        datapoint['judgement'] = judg_list[i][0]
    else:
        datapoint['judgement'] = judg_list[i]
sample = data[:3]
for item in sample:
    print(item)
    print()
# Out:
# {'id': 'ajoneuvot00692', 'judgement': [['positive', 0.5], ['neutral', 0.5]], 'aspects': ['status'], 'left context': 'Tämä . BMW provosoi tarpeettomiin ohituksiin . Liikennevaloissa lähtiessäkin on usein yhden hengen kiihdytyskisat pystyssä . ', 'target': 'Fordin', 'right context': ' ratissa ei tarvitse katsella tätä , vaikka ajotyyli ja nopeus on samoja . Onko tämä sitä kateutta ?'}
#
# {'id': 'ajoneuvot00697', 'judgement': 'positive', 'aspects': ['auto', 'merkki', 'ääni'], 'left context': '', 'target': 'Zetat', 'right context': ' on kyllä upeita . Hyväkuntoiset on vaan aikalailla viety käsistä . Aika paljon noita myös laitellaan , mutta hyvällä maulla mielestäni ( motorsport hengessä ) . Olen ollut parin + 250hp vaparin kyydissä . Suorakutonen laulaa nätisti 8000rpm .'}
#
# {'id': 'ajoneuvot01589', 'judgement': [['neutral', 0.6666666666666666], ['mixed', 0.3333333333333333]], 'aspects': ['hinta', 'piirteet'], 'left context': 'Tässä langassa lienee paras kysyä , mitä tulisi huomioida ', 'target': 'E39 : n', 'right context': ' hankinnassa , niitähän saa jo parilla tonnilla . Ainoat kriteerit : nahkasisusta , ilmastointi , sedan .'}

# %%
# let's divide dat into a train/dev/test batches by amount of labels first
clear_labels = ['positive','neutral','negative', 'mixed', 'unclear']
train_data =[]
dev_data =[]
test_data=[]
#count_unclears = 0
for item in data:
    #while(len(train_data))
    judg = item.get('judgement')
    #print(judg)
    if type(judg) == str: ##sentence has class label with 1.00 weight
        if judg == 'unclear' or judg == 'mixed': # these labels don't really tell us much, so let's try relabel them later
            #count_unclears += 1
            test_data.append(item)
        else:
            #print(judg)
            train_data.append(item)
        #if len(dev_data)/len(data) < 0.2 :    
            #dev_data.append(item)
        #else: 
        #train_data.append(item)
    else: # no single label present, so judgement is an list of lists
        max_val = 0
        max_ind = 0
        for x in judg:
            if x[1]> max_val: 
                max_val = x[1] ## max of precentage values
                max_ind = judg.index(x)
        if max_val >= 0.66: #these sentences have a majority label under 1.00
            #print(max_val)
            label = judg[max_ind][0]
            #print(label)
            item['judgement'] = label
            #if label in clear_labels:
                #dev_data.append(item)
            #else:
                #count_unclears += 1
                #test_data.append(item)
            dev_data.append(item)    
        else:
            test_data.append(item)
from sklearn.model_selection import train_test_split
train_data, dev_data= train_test_split(train_data, test_size=0.3)
print("train: ", len(train_data), ", dev:", len(dev_data), ", test: ", len(test_data))
#print("No of unclear and mixed: ",count_unclears)
#pprint(train_data[:10])
print('-----------------------------------')
#pprint(dev_data[:10])
print('--------------------------')
#pprint(test_data[:10])
# Out:
# train:  386 , dev: 166 , test:  193
# -----------------------------------
# --------------------------

# %% [markdown]
# # Looking for synonymous or similar aspects

# %%
# Let's list the aspects from the data
aspect_list =[] 
space = ' '
for item in data:
    aspects = item['aspects']
    #print(type(aspects))
    #print(aspects)
    if aspects[0] == '' or len(aspects[0]) <3: ##taking out empty or too short aspects to be full word
        pass
    else:
        temp = aspects[0].split(' ')
        if len(temp) > 1:
            for item in temp:
                #print(type(item))
                aspect_list.append(item)
        else:
            aspect_list.append(aspects[0])
print("Aspects list length: ",len(aspect_list))
#print(aspect_list[:100])

# then let's get unique set from the list
aspect_set = set()
for aspect in aspect_list: 
    aspect_set.add(aspect)
print("Unique aspects set length: ",len(aspect_set))
print(aspect_set)
# Out:
# Aspects list length:  778
# Unique aspects set length:  232
# {'aikomus', 'status', 'monipuolisuus', 'helppous', 'hinta-laatusuhde', 'akku', 'ajo-ominaisuudet', 'määrittely', 'moottori', 'mestaruus', 'ansio', 'rahasiirto', 'ajettevuus', 'luotettavuus', 'kaupunki', 'arvot', 'hankaluus', 'juoma', 'kannatus', 'arvostus', 'tarkkuus', 'kunto', 'mielipide', 'korjaus', 'ajo-ominaisuus', 'jousitus', 'rap', 'tietoturva', 'ostospäätös', 'maku', 'sähkö', 'ominaisuudet', 'laatu', 'markkina', 'käytettävys', 'kasetti', 'laa', 'valikoima', 'luotonanto', 'informointi', 'sopivuus', 'tarpeellisuus', 'kustomointi', 'käyttömukavuus', 'annos', 'artisti', 'hyöty', 'esimerkki', 'näkymät', 'hauskuus', 'helppokäyttöisyys', 'kauppa', 'ajomukavuus', 'huoltovarmuus', 'kattavuus', 'taso', 'riski', 'haave', 'ajettavuus', 'yleiskuva', 'groovaavuus', 'pelaaminen', 'suoritus', 'varustetaso', 'yleine', 'kieli', 'yhteensopivuus', 'app', 'ajoneuvo', 'arvio', 'toimintakyky', 'bensankulutus', 'nykyaikaisuus', 'asiakaspalvelu', 'asema', 'kesto', 'korjattavuus', 'auto', 'toiminta', 'raha', 'käytettävyys', 'jääkiekko', 'takuu', 'muotoilu', 'neliveto', 'johto', 'tyyli', 'gpu', 'ennustus', 'itsenäisyy', 'viihde', 'mielenkiinto', 'ulkonäkö', 'helppo', 'tehokuus', 'asennus', 'katsojamäärä', 'kotimaa', 'mukavuudet', 'vaihtoehdot', 'perusteet', 'kauneus', 'ajokokemus', 'hiihto/laskettelu', 'kysymys', 'merkki', 'valta', 'levy', 'esto', 'nautinto', 'läpinäkyvyys', 'asiantuntemus', 'esitys', 'tekninen', 'saatavuus', 'tieto', 'neuvo', 'mielipi', 'keveys', 'kokoomus', 'kannattajakulttuuri', 'keskustelu', 'hiiri', 'kovalevy', 'ohjelma', 'kehittyminen', 'vahvuus', 'hyvä', 'edistyneisyys', 'ruokakauppa', 'kun', 'liikennekäyttäytyminen', 'ikä', 'käyttö', 'hint', 'mielikuva', 'kiinnostavuus', 'golf', 'hieno', 'jämäkkyys', 'hohto', 'käytös', 'pelaaja', 'varaosat', 'sarjataso', 'ominaisuus', 'paino', 'taistelulajit', 'jakelu', 'ergonomia', 'design', 'sijoitus', 'arvo', 'pallo', 'astiat', 'soveltuvuus', 'osaaminen', 'huolto', 'hygienia', 'hinta', 'mielenkiintoisuus', 'ennuste', 'suosittelu', 'joukkuepelaaminen', 'ohje', 'coctail', 'määrä', 'arvostelu', 'voitto', 'vaikeus', 'kielipolitiikka', 'ennakoitavuus', 'kone', 'nopeus', 'yleinen', 'kotimaisuus', 'tehokkuus', 'hakukone', 'blogi', 'tuotevalikoima', 'alkuperä', 'politiikka', 'aika', 'myynti', 'näkemys', 'budjetointi', 'kuntoisuus', 'bonukset', 'mukavuus', 'käyttöjärjestelmä', 'tuttuus', 'iso', 'suorituskyky', 'riskitaso', 'menestys', 'toimivuus', 'kilpailukyky', 'ammattilaine', 'malli', 'arvolisävero', 'koko', 'käyt', 'varustelu', 'ongelma', 'norjalaisuus', 'vaikutus', 'vakiovarusteet', 'sympaattisuus', 'arvostelut', 'kaupunkiajo', 'laitevaatimus', 'kulutus', 'apple', 'tuote', 'tekniikka', 'kestävyys', 'varuste', 'kuntoisuu', 'alusta', 'urheilu', 'käyttökelpoisuus', 'tekopyhyys', 'suosio', 'analyysi', 'hyvyys', 'jalkapallo', 'epäsäännöllisyys', 'harrastus', 'liitokiekko', 'facebook', 'hienoudet', 'pyöräily'}

# %%
# Now we can start looking at the aspects 
# Let's start with some statistics...
from collections import Counter
aspect_counter = Counter()
aspect_counter.update(aspect_list) #aspect_list is the original list
#pprint(aspect_counter)
most_common = aspect_counter.most_common(20)
print()
print("Twenty most commonly aspects used in the annotation data:\n")
for item in most_common:
    print(item)
# Out:
# Twenty most commonly aspects used in the annotation data:
#
# ('laatu', 117)
# ('hinta', 93)
# ('kuntoisuus', 37)
# ('kysymys', 35)
# ('yleinen', 32)
# ('toimivuus', 22)
# ('maku', 22)
# ('käytettävyys', 19)
# ('mielipide', 17)
# ('luotettavuus', 12)
# ('käyttö', 12)
# ('ulkonäkö', 10)
# ('helppous', 7)
# ('ohje', 7)
# ('kestävyys', 6)
# ('ajettavuus', 6)
# ('ominaisuus', 6)
# ('arvo', 5)
# ('yleiskuva', 5)
# ('ikä', 4)

# %% [markdown]
# # 1. USING WORD2VEC

# %%
# this is for the synonym part as the fin-word2vec model is too big for Github
# you can download the model from my Gdrive here: https://drive.google.com/file/d/1spguHkZlP0wmb6hX6NbW6l80Z-Rg46Qb/view?usp=sharing

#mounting Google drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# now let's get a word2vec model for Finnish
import gensim
from gensim.models import word2vec
## for downloading NOTE! dl is Slooowww due to size of the model (14,28 Gb)
model = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/My Drive/Opinnot/KiTe/JoKite/2020/fin-word2vec.bin', binary=True)
model.save_word2vec_format('fin-w2vec.txt', binary=False)

# if already loaded as local .txt
#model = gensim.models.KeyedVectors.load_word2vec_format('fin-w2vec.txt', binary=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-02f721de6353> in <module>()
#       3 from gensim.models import word2vec
#       4 ## for downloading NOTE! dl is Slooowww due to size of the model (14,28 Gb)
# ----> 5 model = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/My Drive/Opinnot/KiTe/JoKite/2020/fin-word2vec.bin', binary=True)
#       6 model.save_word2vec_format('fin-w2vec.txt', binary=False)
#       7
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1436         return _load_word2vec_format(
#    1437             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1438             limit=limit, datatype=datatype)
#    1439
#    1440     def get_keras_embedding(self, train_embeddings=False):
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     176         result = cls(vector_size)
#     177         result.vector_size = vector_size
# --> 178         result.vectors = zeros((vocab_size, vector_size), dtype=datatype)
#     179
#     180         def add_word(word, weights):
#
# KeyboardInterrupt:

# %%
# We can see that there are some malformed words like *käytettävys* or *käytettävyy* which is not a unique aspect from käytettävyys
# So we need to clean this set using Levenshtein if it loads

import difflib

asp_clean_list = list(aspect_set)
saved = []
deleted = []
for item1 in asp_clean_list:
    if item1 in saved or item1 in deleted:
        pass
    if item1 not in model.vocab:
        # let's first check if there is a close match in the uniq_set itself
        closest = difflib.get_close_matches(item1, asp_uniq_list)
        print(closest)
        for x in closest:
            if difflib.SequenceMatcher(None, item1, x).ratio() >= 0.8:
                if item1 ==x:
                    pass
                elif item1 in x:
                    print( item1, x)
                    saved.append(x)
                    deleted.append(item1)
                    #asp_uniq_list.pop(asp_uniq_list.index(item1))
                elif x in item1:
                    print( x, item1)
                    saved.append(item1)
                    #deleted.append(x)
                else:   
                    saved.append(closest[1])
                    deleted.append(closest[0])
    else:
        saved.append(item1)
print("saved: ", saved)
print("deleted: ", deleted)
# Out:
# ['ajettevuus', 'ajettavuus', 'kattavuus']
# ['ajo-ominaisuus', 'ajo-ominaisuudet', 'ominaisuus']
# ominaisuus ajo-ominaisuus
# ['käytettävys', 'käytettävyys', 'kestävyys']
# ['groovaavuus', 'vahvuus', 'korjattavuus']
# ['itsenäisyy']
# ['hiihto/laskettelu']
# ['mielipi', 'mielipide', 'kieli']
# mielipi mielipide
# ['kuntoisuu', 'kuntoisuus', 'kunto']
# kuntoisuu kuntoisuus
# saved:  ['aikomus', 'status', 'monipuolisuus', 'helppous', 'hinta-laatusuhde', 'akku', 'ajo-ominaisuudet', 'määrittely', 'moottori', 'mestaruus', 'ansio', 'rahasiirto', 'ajettavuus', 'luotettavuus', 'kaupunki', 'arvot', 'hankaluus', 'juoma', 'kannatus', 'arvostus', 'tarkkuus', 'kunto', 'mielipide', 'korjaus', 'ajo-ominaisuudet', 'ajo-ominaisuus', 'jousitus', 'rap', 'tietoturva', 'ostospäätös', 'maku', 'sähkö', 'ominaisuudet', 'laatu', 'markkina', 'käytettävyys', 'kasetti', 'laa', 'valikoima', 'luotonanto', 'informointi', 'sopivuus', 'tarpeellisuus', 'kustomointi', 'käyttömukavuus', 'annos', 'artisti', 'hyöty', 'esimerkki', 'näkymät', 'hauskuus', 'helppokäyttöisyys', 'kauppa', 'ajomukavuus', 'huoltovarmuus', 'kattavuus', 'taso', 'riski', 'haave', 'ajettavuus', 'yleiskuva', 'pelaaminen', 'suoritus', 'varustetaso', 'yleine', 'kieli', 'yhteensopivuus', 'app', 'ajoneuvo', 'arvio', 'toimintakyky', 'bensankulutus', 'nykyaikaisuus', 'asiakaspalvelu', 'asema', 'kesto', 'korjattavuus', 'auto', 'toiminta', 'raha', 'käytettävyys', 'jääkiekko', 'takuu', 'muotoilu', 'neliveto', 'johto', 'tyyli', 'gpu', 'ennustus', 'viihde', 'mielenkiinto', 'ulkonäkö', 'helppo', 'tehokuus', 'asennus', 'katsojamäärä', 'kotimaa', 'mukavuudet', 'vaihtoehdot', 'perusteet', 'kauneus', 'ajokokemus', 'kysymys', 'merkki', 'valta', 'levy', 'esto', 'nautinto', 'läpinäkyvyys', 'asiantuntemus', 'esitys', 'tekninen', 'saatavuus', 'tieto', 'neuvo', 'mielipide', 'keveys', 'kokoomus', 'kannattajakulttuuri', 'keskustelu', 'hiiri', 'kovalevy', 'ohjelma', 'kehittyminen', 'vahvuus', 'hyvä', 'edistyneisyys', 'ruokakauppa', 'kun', 'liikennekäyttäytyminen', 'ikä', 'käyttö', 'hint', 'mielikuva', 'kiinnostavuus', 'golf', 'hieno', 'jämäkkyys', 'hohto', 'käytös', 'pelaaja', 'varaosat', 'sarjataso', 'ominaisuus', 'paino', 'taistelulajit', 'jakelu', 'ergonomia', 'design', 'sijoitus', 'arvo', 'pallo', 'astiat', 'soveltuvuus', 'osaaminen', 'huolto', 'hygienia', 'hinta', 'mielenkiintoisuus', 'ennuste', 'suosittelu', 'joukkuepelaaminen', 'ohje', 'coctail', 'määrä', 'arvostelu', 'voitto', 'vaikeus', 'kielipolitiikka', 'ennakoitavuus', 'kone', 'nopeus', 'yleinen', 'kotimaisuus', 'tehokkuus', 'hakukone', 'blogi', 'tuotevalikoima', 'alkuperä', 'politiikka', 'aika', 'myynti', 'näkemys', 'budjetointi', 'kuntoisuus', 'bonukset', 'mukavuus', 'käyttöjärjestelmä', 'tuttuus', 'iso', 'suorituskyky', 'riskitaso', 'menestys', 'toimivuus', 'kilpailukyky', 'ammattilaine', 'malli', 'arvolisävero', 'koko', 'käyt', 'varustelu', 'ongelma', 'norjalaisuus', 'vaikutus', 'vakiovarusteet', 'sympaattisuus', 'arvostelut', 'kaupunkiajo', 'laitevaatimus', 'kulutus', 'apple', 'tuote', 'tekniikka', 'kestävyys', 'varuste', 'kuntoisuus', 'alusta', 'urheilu', 'käyttökelpoisuus', 'tekopyhyys', 'suosio', 'analyysi', 'hyvyys', 'jalkapallo', 'epäsäännöllisyys', 'harrastus', 'liitokiekko', 'facebook', 'hienoudet', 'pyöräily']
# deleted:  ['ajettevuus', 'ajo-ominaisuus', 'käytettävys', 'mielipi', 'kuntoisuu']

# %%
# then let's use the larger vocab

for item in saved:
    if item not in model.vocab:
        
        print(item)
        #print("not in vocab:",item1)
        closest = difflib.get_close_matches(item1, model.vocab)
        print(closest)
        for x in closest:
            if difflib.SequenceMatcher(None, x, item1).ratio()== 1.00:
                pass
            elif difflib.SequenceMatcher(None, x, item1).ratio() >= 0.7:
                if item1 in x:
                    print( item1, x)
                    saved.append(x)
                    deleted.append(item1)
                    #asp_uniq_list.pop(asp_uniq_list.index(item1))
                elif x in item1:
                    print( x, item1)
                    saved.append(item1)
                    deleted.append(x)
            else:   
                saved.append(closest[1])
                deleted.append(closest[0])
                #asp_uniq_list[asp_uniq_list.index(item1)] = word
#for item1 in asp_uniq_list:
 #   for item2 in asp_uniq_list:
  #      if len(item1) > len(item2):
   #         short = item2x
    #        long = item1
     #   else:
      #      short = item1
       #     long = item2
       # if difflib.SequenceMatcher(None, long, short).ratio() == 1.00:
        #    pass
       # elif difflib.SequenceMatcher(None, long, short).ratio() >= 0.9 and difflib.SequenceMatcher(None, long, short).ratio()< 1.00:
        #    print( long, short)
         #   asp_uniq_list[asp_uniq_list.index(short)] = long
          #  #asp_uniq_list.pop(asp_uniq_list.index(item2))
    
        
        
print("no of saved items:",len(saved))
asp_uniq_set = set()
for item in saved:
    asp_uniq_set.add(item)
print(len(asp_clean_list))
print(len(asp_uniq_set))
print("saved: ", saved)
print("deleted: ", deleted)
# Out:
# ajo-ominaisuus
# ['pyöräily', 'pyöräilyä', 'pyöräilyt']
# pyöräily pyöräilyä
# pyöräily pyöräilyt
# no of saved items: 236
# 232
# 227
# saved:  ['aikomus', 'status', 'monipuolisuus', 'helppous', 'hinta-laatusuhde', 'akku', 'ajo-ominaisuudet', 'määrittely', 'moottori', 'mestaruus', 'ansio', 'rahasiirto', 'ajettavuus', 'luotettavuus', 'kaupunki', 'arvot', 'hankaluus', 'juoma', 'kannatus', 'arvostus', 'tarkkuus', 'kunto', 'mielipide', 'korjaus', 'ajo-ominaisuudet', 'ajo-ominaisuus', 'jousitus', 'rap', 'tietoturva', 'ostospäätös', 'maku', 'sähkö', 'ominaisuudet', 'laatu', 'markkina', 'käytettävyys', 'kasetti', 'laa', 'valikoima', 'luotonanto', 'informointi', 'sopivuus', 'tarpeellisuus', 'kustomointi', 'käyttömukavuus', 'annos', 'artisti', 'hyöty', 'esimerkki', 'näkymät', 'hauskuus', 'helppokäyttöisyys', 'kauppa', 'ajomukavuus', 'huoltovarmuus', 'kattavuus', 'taso', 'riski', 'haave', 'ajettavuus', 'yleiskuva', 'pelaaminen', 'suoritus', 'varustetaso', 'yleine', 'kieli', 'yhteensopivuus', 'app', 'ajoneuvo', 'arvio', 'toimintakyky', 'bensankulutus', 'nykyaikaisuus', 'asiakaspalvelu', 'asema', 'kesto', 'korjattavuus', 'auto', 'toiminta', 'raha', 'käytettävyys', 'jääkiekko', 'takuu', 'muotoilu', 'neliveto', 'johto', 'tyyli', 'gpu', 'ennustus', 'viihde', 'mielenkiinto', 'ulkonäkö', 'helppo', 'tehokuus', 'asennus', 'katsojamäärä', 'kotimaa', 'mukavuudet', 'vaihtoehdot', 'perusteet', 'kauneus', 'ajokokemus', 'kysymys', 'merkki', 'valta', 'levy', 'esto', 'nautinto', 'läpinäkyvyys', 'asiantuntemus', 'esitys', 'tekninen', 'saatavuus', 'tieto', 'neuvo', 'mielipide', 'keveys', 'kokoomus', 'kannattajakulttuuri', 'keskustelu', 'hiiri', 'kovalevy', 'ohjelma', 'kehittyminen', 'vahvuus', 'hyvä', 'edistyneisyys', 'ruokakauppa', 'kun', 'liikennekäyttäytyminen', 'ikä', 'käyttö', 'hint', 'mielikuva', 'kiinnostavuus', 'golf', 'hieno', 'jämäkkyys', 'hohto', 'käytös', 'pelaaja', 'varaosat', 'sarjataso', 'ominaisuus', 'paino', 'taistelulajit', 'jakelu', 'ergonomia', 'design', 'sijoitus', 'arvo', 'pallo', 'astiat', 'soveltuvuus', 'osaaminen', 'huolto', 'hygienia', 'hinta', 'mielenkiintoisuus', 'ennuste', 'suosittelu', 'joukkuepelaaminen', 'ohje', 'coctail', 'määrä', 'arvostelu', 'voitto', 'vaikeus', 'kielipolitiikka', 'ennakoitavuus', 'kone', 'nopeus', 'yleinen', 'kotimaisuus', 'tehokkuus', 'hakukone', 'blogi', 'tuotevalikoima', 'alkuperä', 'politiikka', 'aika', 'myynti', 'näkemys', 'budjetointi', 'kuntoisuus', 'bonukset', 'mukavuus', 'käyttöjärjestelmä', 'tuttuus', 'iso', 'suorituskyky', 'riskitaso', 'menestys', 'toimivuus', 'kilpailukyky', 'ammattilaine', 'malli', 'arvolisävero', 'koko', 'käyt', 'varustelu', 'ongelma', 'norjalaisuus', 'vaikutus', 'vakiovarusteet', 'sympaattisuus', 'arvostelut', 'kaupunkiajo', 'laitevaatimus', 'kulutus', 'apple', 'tuote', 'tekniikka', 'kestävyys', 'varuste', 'kuntoisuus', 'alusta', 'urheilu', 'käyttökelpoisuus', 'tekopyhyys', 'suosio', 'analyysi', 'hyvyys', 'jalkapallo', 'epäsäännöllisyys', 'harrastus', 'liitokiekko', 'facebook', 'hienoudet', 'pyöräily', 'pyöräilyä', 'pyöräilyt', 'pyöräilyä', 'pyöräilyt', 'pyöräilyä', 'pyöräilyt']
# deleted:  ['ajettevuus', 'ajo-ominaisuus', 'käytettävys', 'mielipi', 'kuntoisuu', 'pyöräily', 'pyöräily', 'pyöräily', 'pyöräily', 'pyöräily', 'pyöräily']

# %% [markdown]
# Then we can try to find synonymy or similarity between the aspects by using the word2vec model:

# %%
# creating a matrix of similarity scores
similarities = []
for aspect in asp_uniq_set:
    for x in asp_uniq_set:
        if aspect in model.vocab and x in model.vocab:
            similarity = model.similarity(aspect,x)
            similarities.append([aspect,x,similarity])
#pprint(similarities[:50])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# Let's convert this matrix to a dataframe with integer values for readability:

# %%
import pandas as p
#import numpy as np

similarity_matrix = p.DataFrame(None, index=aspect_set, columns=aspect_set)
#print(similarity_matrix)
for item in similarities:
    similarity_matrix.loc[item[0], item[1]] = int(item[2]*100)
#print(similarity_matrix)

# %%
import math
# 
sim_dict_matrix = similarity_matrix.to_dict(orient='index')
#print(sim_dict_matrix)
aspect_comparison_dict = {}
max = ["","", 0]
min= ["","", 0]
for key, value in sim_dict_matrix.items():
    #print(key)
    closest={}
    farthest={}
    # find 4 closest
    desc_ord = sorted(value.items(), key=lambda x:x[1], reverse=True)
    #print(desc_ord)
    for k,v in desc_ord[1:10]:
        if not math.isnan(v) and k != key:
            if len(closest)<4:
                closest.update({k:v})
                if v > max[2]:
                    max=[key,k,v]
            else:break
    # find 4 least similar
    asc_ord = sorted(value.items(), key=lambda x:x[1], reverse=False)
    for k,v in asc_ord[1:10]:
        if not math.isnan(v) and k!=key:
            if len(farthest)<4:
                farthest.update({k:v})
                if v < min[2]:
                    min=[key,k,v]
            else:break
    #farthest ={"farthest_5":row_ord[len(row_ord)-1:-6:-1]}
    #print("Closest: ",closest)
    #print("Farthest: ",farthest)
    if bool(closest) and bool(farthest):
        aspect_comparison_dict[key]={}
        aspect_comparison_dict[key].update({"Closest":sorted(closest.items(), key=lambda x:x[1], reverse=True)})
        aspect_comparison_dict[key].update({"Farthest":sorted(farthest.items(), key=lambda x:x[1], reverse=False)})    
pprint(aspect_comparison_dict)
print()
print("Most similar aspects: ",max)
print("Least similar aspects: " ,min)
# Out:
# {'aika': {'Closest': [('ostospäätös', 22),
#                       ('hankaluus', 20),
#                       ('maku', 20),
#                       ('hinta-laatusuhde', 17)],
#           'Farthest': [('kattavuus', -4),
#                        ('monipuolisuus', -3),
#                        ('luotettavuus', -3),
#                        ('sopivuus', -3)]},
#  'aikomus': {'Closest': [('kannatus', 17),
#                          ('kunto', 16),
#                          ('mielipide', 15),
#                          ('status', 14)],
#              'Farthest': [('laa', -3),
#                           ('ajo-ominaisuudet', -2),
#                           ('ansio', -2),
#                           ('tarkkuus', -2)]},
#  'ajettavuus': {'Closest': [('ajomukavuus', 75),
#                             ('ajo-ominaisuudet', 74),
#                             ('jousitus', 71),
#                             ('moottori', 59)],
#                 'Farthest': [('haave', -5),
#                              ('artisti', -1),
#                              ('kaupunki', 0),
#                              ('mielipide', 0)]},
#  'ajo-ominaisuudet': {'Closest': [('ajettavuus', 74),
#                                   ('ajomukavuus', 70),
#                                   ('jousitus', 66),
#                                   ('moottori', 57)],
#                       'Farthest': [('artisti', -6),
#                                    ('kauppa', -4),
#                                    ('aikomus', -2),
#                                    ('määrittely', -1)]},
#  'ajokokemus': {'Closest': [('ajomukavuus', 59),
#                             ('jousitus', 50),
#                             ('moottori', 45),
#                             ('käyttömukavuus', 43)],
#                 'Farthest': [('määrittely', 2),
#                              ('kaupunki', 2),
#                              ('rap', 4),
#                              ('artisti', 4)]},
#  'ajomukavuus': {'Closest': [('käyttömukavuus', 72),
#                              ('ajo-ominaisuudet', 70),
#                              ('jousitus', 62)],
#                  'Farthest': [('artisti', -1),
#                               ('haave', -1),
#                               ('mielipide', 0),
#                               ('ostospäätös', 0)]},
#  'ajoneuvo': {'Closest': [('jousitus', 36),
#                           ('ajo-ominaisuudet', 32),
#                           ('korjaus', 30),
#                           ('sähkö', 30)],
#               'Farthest': [('näkymät', -6),
#                            ('arvostus', -5),
#                            ('laa', -5),
#                            ('arvot', -3)]},
#  'akku': {'Closest': [('moottori', 52),
#                       ('kasetti', 50),
#                       ('tarkkuus', 35),
#                       ('jousitus', 33)],
#           'Farthest': [('ansio', -7),
#                        ('laa', -7),
#                        ('määrittely', -6),
#                        ('informointi', -4)]},
#  'alkuperä': {'Closest': [('tarpeellisuus', 33),
#                           ('hankaluus', 30),
#                           ('laatu', 30),
#                           ('määrittely', 30)],
#               'Farthest': [('moottori', -9),
#                            ('akku', -7),
#                            ('ajo-ominaisuudet', -4),
#                            ('näkymät', -3)]},
#  'alusta': {'Closest': [('helppokäyttöisyys', 11),
#                         ('aikomus', 10),
#                         ('moottori', 10),
#                         ('jousitus', 10)],
#             'Farthest': [('riski', -6),
#                          ('status', -5),
#                          ('hyöty', -5),
#                          ('mielipide', -4)]},
#  'ammattilaine': {'Closest': [('ostospäätös', 23),
#                               ('artisti', 19),
#                               ('rap', 13),
#                               ('akku', 12)],
#                   'Farthest': [('huoltovarmuus', -9),
#                                ('valikoima', -7),
#                                ('informointi', -7),
#                                ('tarpeellisuus', -7)]},
#  'analyysi': {'Closest': [('yleiskuva', 44),
#                           ('esimerkki', 41),
#                           ('informointi', 27),
#                           ('kattavuus', 27)],
#               'Farthest': [('juoma', -2),
#                            ('akku', -1),
#                            ('ostospäätös', 0),
#                            ('sähkö', 0)]},
#  'annos': {'Closest': [('juoma', 45),
#                        ('maku', 36),
#                        ('taso', 21),
#                        ('hinta-laatusuhde', 20)],
#            'Farthest': [('sähkö', -2),
#                         ('luotettavuus', -1),
#                         ('laa', -1),
#                         ('informointi', -1)]},
#  'ansio': {'Closest': [('arvostus', 26),
#                        ('hankaluus', 24),
#                        ('rahasiirto', 22),
#                        ('määrittely', 19)],
#            'Farthest': [('kasetti', -4),
#                         ('aikomus', -2),
#                         ('ajo-ominaisuudet', 0),
#                         ('moottori', 0)]},
#  'app': {'Closest': [('kustomointi', 26),
#                      ('tietoturva', 23),
#                      ('akku', 22),
#                      ('ominaisuudet', 17)],
#          'Farthest': [('sähkö', -6),
#                       ('huoltovarmuus', -5),
#                       ('kannatus', -4),
#                       ('sopivuus', -4)]},
#  'apple': {'Closest': [('tietoturva', 25),
#                        ('akku', 21),
#                        ('markkina', 21),
#                        ('korjaus', 17)],
#            'Farthest': [('määrittely', -6),
#                         ('kattavuus', -5),
#                         ('ansio', -3),
#                         ('kannatus', -1)]},
#  'artisti': {'Closest': [('rap', 38),
#                          ('esimerkki', 16),
#                          ('kasetti', 15),
#                          ('ostospäätös', 13)],
#              'Farthest': [('näkymät', -7),
#                           ('ajo-ominaisuudet', -6),
#                           ('yleiskuva', -5),
#                           ('jousitus', -4)]},
#  'arvio': {'Closest': [('mielipide', 36),
#                        ('annos', 17),
#                        ('taso', 17),
#                        ('kannatus', 15)],
#            'Farthest': [('hauskuus', -3),
#                         ('ostospäätös', -2),
#                         ('luotonanto', -2),
#                         ('monipuolisuus', 0)]},
#  'arvo': {'Closest': [('arvostus', 43),
#                       ('taso', 42),
#                       ('hyöty', 35),
#                       ('ansio', 31)],
#           'Farthest': [('laa', -4),
#                        ('ostospäätös', -2),
#                        ('juoma', 0),
#                        ('moottori', 1)]},
#  'arvolisävero': {'Closest': [('taso', 24),
#                               ('kannatus', 22),
#                               ('ansio', 21),
#                               ('kauppa', 21)],
#                   'Farthest': [('haave', -8),
#                                ('laa', -5),
#                                ('aikomus', -3),
#                                ('moottori', -1)]},
#  'arvostelu': {'Closest': [('mielipide', 15),
#                            ('luotettavuus', 13),
#                            ('rahasiirto', 12),
#                            ('status', 9)],
#                'Farthest': [('ansio', 0),
#                             ('artisti', 0),
#                             ('akku', 1),
#                             ('kaupunki', 1)]},
#  'arvostelut': {'Closest': [('ominaisuudet', 17),
#                             ('ajo-ominaisuudet', 13),
#                             ('arvot', 12),
#                             ('aikomus', 7)],
#                 'Farthest': [('riski', -7),
#                              ('määrittely', -3),
#                              ('kasetti', -3),
#                              ('mielipide', -2)]},
#  'arvostus': {'Closest': [('luotettavuus', 49),
#                           ('arvot', 41),
#                           ('status', 33),
#                           ('helppous', 32)],
#               'Farthest': [('akku', -3),
#                            ('korjaus', -2),
#                            ('kaupunki', -1),
#                            ('moottori', 1)]},
#  'arvot': {'Closest': [('ominaisuudet', 53),
#                        ('arvostus', 41),
#                        ('luotettavuus', 37),
#                        ('status', 30)],
#            'Farthest': [('kasetti', -6),
#                         ('kustomointi', -5),
#                         ('juoma', -3),
#                         ('artisti', -3)]},
#  'asema': {'Closest': [('arvostus', 50),
#                        ('huoltovarmuus', 36),
#                        ('taso', 36),
#                        ('kattavuus', 34)],
#            'Farthest': [('artisti', 1),
#                         ('juoma', 2),
#                         ('jousitus', 2),
#                         ('ajo-ominaisuudet', 3)]},
#  'asennus': {'Closest': [('korjaus', 69),
#                          ('kustomointi', 46),
#                          ('sähkö', 35),
#                          ('rahasiirto', 23)],
#              'Farthest': [('juoma', -4),
#                           ('maku', -4),
#                           ('arvostus', -3),
#                           ('kaupunki', -2)]},
#  'asiakaspalvelu': {'Closest': [('valikoima', 26),
#                                 ('luotettavuus', 21),
#                                 ('laatu', 21),
#                                 ('rahasiirto', 16)],
#                     'Farthest': [('artisti', -8),
#                                  ('haave', -8),
#                                  ('riski', -6),
#                                  ('esimerkki', -2)]},
#  'asiantuntemus': {'Closest': [('luotettavuus', 65),
#                                ('helppokäyttöisyys', 50),
#                                ('laatu', 48),
#                                ('arvostus', 48)],
#                    'Farthest': [('akku', 0),
#                                 ('ostospäätös', 0),
#                                 ('haave', 0),
#                                 ('kaupunki', 1)]},
#  'astiat': {'Closest': [('sähkö', 16),
#                         ('näkymät', 15),
#                         ('juoma', 14),
#                         ('ansio', 4)],
#             'Farthest': [('esimerkki', -7),
#                          ('tarpeellisuus', -6),
#                          ('huoltovarmuus', -6),
#                          ('status', -5)]},
#  'auto': {'Closest': [('jousitus', 42),
#                       ('akku', 36),
#                       ('ajo-ominaisuudet', 35),
#                       ('kaupunki', 21)],
#           'Farthest': [('monipuolisuus', -7),
#                        ('laa', -4),
#                        ('arvot', -3),
#                        ('informointi', -2)]},
#  'bensankulutus': {'Closest': [('ajettavuus', 48),
#                                ('jousitus', 41),
#                                ('ajo-ominaisuudet', 39),
#                                ('sähkö', 34)],
#                    'Farthest': [('määrittely', -2),
#                                 ('sopivuus', -1),
#                                 ('laa', 0),
#                                 ('informointi', 0)]},
#  'blogi': {'Closest': [('mielipide', 21),
#                        ('esimerkki', 20),
#                        ('status', 17),
#                        ('artisti', 17)],
#            'Farthest': [('ajo-ominaisuudet', -6),
#                         ('jousitus', -5),
#                         ('ajomukavuus', -4),
#                         ('kattavuus', -4)]},
#  'bonukset': {'Closest': [('luotonanto', 17),
#                           ('ominaisuudet', 16),
#                           ('ansio', 15),
#                           ('ajo-ominaisuudet', 14)],
#               'Farthest': [('kasetti', -5),
#                            ('aikomus', -3),
#                            ('kaupunki', -2),
#                            ('kannatus', -1)]},
#  'budjetointi': {'Closest': [('informointi', 42),
#                              ('kattavuus', 38),
#                              ('tietoturva', 37),
#                              ('luotettavuus', 36)],
#                  'Farthest': [('ostospäätös', -8),
#                               ('artisti', -6),
#                               ('kasetti', -4),
#                               ('rap', -3)]},
#  'coctail': {'Closest': [('juoma', 47),
#                          ('maku', 40),
#                          ('annos', 38),
#                          ('valikoima', 22)],
#              'Farthest': [('arvot', -3),
#                           ('kannatus', -3),
#                           ('tietoturva', -2),
#                           ('luotettavuus', -1)]},
#  'design': {'Closest': [('helppokäyttöisyys', 34),
#                         ('käyttömukavuus', 28),
#                         ('laatu', 23),
#                         ('monipuolisuus', 22)],
#             'Farthest': [('ostospäätös', -3),
#                          ('mestaruus', -2),
#                          ('riski', -2),
#                          ('kannatus', -1)]},
#  'edistyneisyys': {'Closest': [('helppokäyttöisyys', 40),
#                                ('käyttömukavuus', 39),
#                                ('tarkkuus', 37),
#                                ('ominaisuudet', 36)],
#                    'Farthest': [('haave', 1),
#                                 ('mielipide', 2),
#                                 ('artisti', 2),
#                                 ('rap', 3)]},
#  'ennakoitavuus': {'Closest': [('luotettavuus', 52),
#                                ('laatu', 49),
#                                ('huoltovarmuus', 48),
#                                ('monipuolisuus', 47)],
#                    'Farthest': [('kasetti', -4),
#                                 ('artisti', -3),
#                                 ('akku', 0),
#                                 ('kaupunki', 0)]},
#  'ennuste': {'Closest': [('kattavuus', 18),
#                          ('taso', 18),
#                          ('markkina', 17),
#                          ('mestaruus', 16)],
#              'Farthest': [('helppokäyttöisyys', -4),
#                           ('juoma', -3),
#                           ('hauskuus', -3),
#                           ('monipuolisuus', -2)]},
#  'ennustus': {'Closest': [('haave', 33),
#                           ('esimerkki', 25),
#                           ('mielipide', 20),
#                           ('markkina', 16)],
#               'Farthest': [('helppokäyttöisyys', -13),
#                            ('ajo-ominaisuudet', -9),
#                            ('monipuolisuus', -6),
#                            ('ajomukavuus', -6)]},
#  'epäsäännöllisyys': {'Closest': [('hankaluus', 43),
#                                   ('ansio', 30),
#                                   ('arvostus', 27),
#                                   ('helppous', 26)],
#                       'Farthest': [('mestaruus', -5),
#                                    ('rahasiirto', -5),
#                                    ('kaupunki', -5),
#                                    ('laa', -5)]},
#  'ergonomia': {'Closest': [('käyttömukavuus', 75),
#                            ('helppokäyttöisyys', 72),
#                            ('ajomukavuus', 62),
#                            ('laatu', 57)],
#                'Farthest': [('haave', -3),
#                             ('aikomus', -2),
#                             ('kaupunki', -2),
#                             ('ostospäätös', -1)]},
#  'esimerkki': {'Closest': [('yleiskuva', 32), ('hinta-laatusuhde', 20)],
#                'Farthest': [('ostospäätös', -1),
#                             ('akku', 0),
#                             ('ajo-ominaisuudet', 0),
#                             ('laa', 0)]},
#  'esitys': {'Closest': [('esimerkki', 23),
#                         ('mielipide', 18),
#                         ('annos', 18),
#                         ('taso', 18)],
#             'Farthest': [('laa', -9),
#                          ('sopivuus', -6),
#                          ('ominaisuudet', -5),
#                          ('riski', -4)]},
#  'esto': {'Closest': [('tietoturva', 30),
#                       ('ominaisuudet', 19),
#                       ('korjaus', 17),
#                       ('hankaluus', 15)],
#           'Farthest': [('arvostus', -6),
#                        ('haave', -6),
#                        ('mestaruus', -5),
#                        ('laa', -4)]},
#  'facebook': {'Closest': [('tietoturva', 20),
#                           ('mielipide', 19),
#                           ('rahasiirto', 10),
#                           ('helppous', 8)],
#               'Farthest': [('annos', -10),
#                            ('hinta-laatusuhde', -9),
#                            ('mestaruus', -9),
#                            ('sopivuus', -9)]},
#  'golf': {'Closest': [('hauskuus', 21),
#                       ('kunto', 20),
#                       ('ajo-ominaisuudet', 17),
#                       ('juoma', 14)],
#           'Farthest': [('artisti', -7),
#                        ('tarpeellisuus', -6),
#                        ('huoltovarmuus', -6),
#                        ('ostospäätös', -4)]},
#  'gpu': {'Closest': [('moottori', 36),
#                      ('tarkkuus', 32),
#                      ('kasetti', 31),
#                      ('kustomointi', 30)],
#          'Farthest': [('kaupunki', -7),
#                       ('arvostus', -7),
#                       ('rap', -5),
#                       ('mestaruus', -3)]},
#  'haave': {'Closest': [('aikomus', 27),
#                        ('mestaruus', 22),
#                        ('hyöty', 19),
#                        ('hankaluus', 16)],
#            'Farthest': [('helppokäyttöisyys', -9),
#                         ('ominaisuudet', -7),
#                         ('laatu', -7),
#                         ('hinta-laatusuhde', -6)]},
#  'hakukone': {'Closest': [('tietoturva', 19),
#                           ('kustomointi', 19),
#                           ('määrittely', 16),
#                           ('kattavuus', 15)],
#               'Farthest': [('tarpeellisuus', -3),
#                            ('kannatus', -2),
#                            ('monipuolisuus', -1),
#                            ('ajo-ominaisuudet', -1)]},
#  'hankaluus': {'Closest': [('hyöty', 43),
#                            ('hauskuus', 38),
#                            ('helppous', 36),
#                            ('monipuolisuus', 35)],
#                'Farthest': [('laa', -4),
#                             ('näkymät', 0),
#                             ('kauppa', 0),
#                             ('mestaruus', 1)]},
#  'harrastus': {'Closest': [('hauskuus', 38),
#                            ('kunto', 27),
#                            ('arvostus', 25),
#                            ('hankaluus', 22)],
#                'Farthest': [('jousitus', -1),
#                             ('tarkkuus', 0),
#                             ('sähkö', 0),
#                             ('kasetti', 0)]},
#  'hauskuus': {'Closest': [('monipuolisuus', 42),
#                           ('hankaluus', 38),
#                           ('arvostus', 37),
#                           ('helppous', 37)],
#               'Farthest': [('kaupunki', -2),
#                            ('korjaus', -2),
#                            ('laa', -2),
#                            ('sähkö', -1)]},
#  'helppo': {'Closest': [('helppokäyttöisyys', 20),
#                         ('hankaluus', 19),
#                         ('helppous', 17),
#                         ('hinta-laatusuhde', 16)],
#             'Farthest': [('kaupunki', -5),
#                          ('sähkö', -5),
#                          ('kauppa', -4),
#                          ('mestaruus', -2)]},
#  'helppokäyttöisyys': {'Closest': [('käyttömukavuus', 73),
#                                    ('helppous', 69),
#                                    ('luotettavuus', 68),
#                                    ('monipuolisuus', 67)],
#                        'Farthest': [('kaupunki', -3),
#                                     ('mestaruus', -1),
#                                     ('laa', 0),
#                                     ('artisti', 0)]},
#  'helppous': {'Closest': [('helppokäyttöisyys', 69),
#                           ('monipuolisuus', 68),
#                           ('luotettavuus', 56),
#                           ('laatu', 52)],
#               'Farthest': [('kaupunki', -4),
#                            ('kasetti', -3),
#                            ('haave', -3),
#                            ('mestaruus', 0)]},
#  'hieno': {'Closest': [('esimerkki', 20),
#                        ('hauskuus', 20),
#                        ('ostospäätös', 19),
#                        ('maku', 19)],
#            'Farthest': [('sähkö', -8),
#                         ('tietoturva', -6),
#                         ('luotonanto', -5),
#                         ('riski', -4)]},
#  'hienoudet': {'Closest': [('ominaisuudet', 52),
#                            ('hauskuus', 31),
#                            ('helppokäyttöisyys', 28),
#                            ('ajo-ominaisuudet', 27)],
#                'Farthest': [('aikomus', -4),
#                             ('kannatus', -4),
#                             ('rap', -4),
#                             ('markkina', -3)]},
#  'hiiri': {'Closest': [('kasetti', 29),
#                        ('tarkkuus', 24),
#                        ('kustomointi', 23),
#                        ('moottori', 19)],
#            'Farthest': [('arvot', -6),
#                         ('arvostus', -6),
#                         ('mestaruus', -5),
#                         ('monipuolisuus', -4)]},
#  'hint': {'Closest': [('rap', 16),
#                       ('rahasiirto', 12),
#                       ('laa', 12),
#                       ('kasetti', 8)],
#           'Farthest': [('riski', -7),
#                        ('arvostus', -6),
#                        ('arvot', -5),
#                        ('ominaisuudet', -5)]},
#  'hinta': {'Closest': [('laatu', 35),
#                        ('taso', 34),
#                        ('hinta-laatusuhde', 27),
#                        ('kattavuus', 23)],
#            'Farthest': [('ostospäätös', -5),
#                         ('rap', -1),
#                         ('kaupunki', 0),
#                         ('informointi', 1)]},
#  'hinta-laatusuhde': {'Closest': [('laatu', 51),
#                                   ('käyttömukavuus', 44),
#                                   ('ajettavuus', 43),
#                                   ('maku', 38)],
#                       'Farthest': [('haave', -6),
#                                    ('sähkö', -4),
#                                    ('status', -1),
#                                    ('riski', -1)]},
#  'hohto': {'Closest': [('hauskuus', 34),
#                        ('maku', 30),
#                        ('monipuolisuus', 23),
#                        ('arvostus', 22)],
#            'Farthest': [('aikomus', -4),
#                         ('informointi', -4),
#                         ('määrittely', -3),
#                         ('korjaus', -1)]},
#  'huolto': {'Closest': [('korjaus', 70),
#                         ('sähkö', 37),
#                         ('kunto', 27),
#                         ('luotettavuus', 21)],
#             'Farthest': [('näkymät', -6),
#                          ('maku', -5),
#                          ('kannatus', -4),
#                          ('aikomus', -3)]},
#  'huoltovarmuus': {'Closest': [('laatu', 38),
#                                ('luotettavuus', 35),
#                                ('sähkö', 35),
#                                ('kattavuus', 30)],
#                    'Farthest': [('artisti', -1),
#                                 ('kasetti', 0),
#                                 ('annos', 0),
#                                 ('näkymät', 0)]},
#  'hygienia': {'Closest': [('laatu', 43),
#                           ('kunto', 40),
#                           ('luotettavuus', 35),
#                           ('monipuolisuus', 31)],
#               'Farthest': [('ostospäätös', -6),
#                            ('haave', -5),
#                            ('moottori', -2),
#                            ('kaupunki', -1)]},
#  'hyvyys': {'Closest': [('hauskuus', 45),
#                         ('arvostus', 41),
#                         ('luotettavuus', 37),
#                         ('laatu', 28)],
#             'Farthest': [('korjaus', -1),
#                          ('näkymät', -1),
#                          ('sähkö', 0),
#                          ('markkina', 0)]},
#  'hyvä': {'Closest': [('hinta-laatusuhde', 31),
#                       ('kunto', 29),
#                       ('maku', 25),
#                       ('luotettavuus', 16)],
#           'Farthest': [('sähkö', -2),
#                        ('luotonanto', -2),
#                        ('artisti', -1),
#                        ('akku', 0)]},
#  'hyöty': {'Closest': [('hankaluus', 43),
#                        ('ansio', 34),
#                        ('kattavuus', 34),
#                        ('riski', 33)],
#            'Farthest': [('laa', -6),
#                         ('jousitus', 0),
#                         ('juoma', 1),
#                         ('kasetti', 1)]},
#  'ikä': {'Closest': [('kunto', 21),
#                      ('taso', 17),
#                      ('informointi', 15),
#                      ('hauskuus', 15)],
#          'Farthest': [('artisti', -3),
#                       ('kaupunki', -2),
#                       ('ostospäätös', -1),
#                       ('sähkö', -1)]},
#  'informointi': {'Closest': [('luotettavuus', 37),
#                              ('tarpeellisuus', 34),
#                              ('kattavuus', 30),
#                              ('korjaus', 26)],
#                  'Farthest': [('ostospäätös', -9),
#                               ('kasetti', -8),
#                               ('akku', -4),
#                               ('artisti', -2)]},
#  'iso': {'Closest': [('hankaluus', 21),
#                      ('haave', 21),
#                      ('kasetti', 18),
#                      ('riski', 18)],
#          'Farthest': [('määrittely', -6),
#                       ('luotettavuus', -6),
#                       ('arvot', -6),
#                       ('ominaisuudet', -6)]},
#  'jakelu': {'Closest': [('tietoturva', 33),
#                         ('kustomointi', 33),
#                         ('määrittely', 32),
#                         ('helppokäyttöisyys', 32)],
#             'Farthest': [('arvot', -4),
#                          ('laa', -4),
#                          ('ostospäätös', -3),
#                          ('hinta-laatusuhde', -2)]},
#  'jalkapallo': {'Closest': [('rap', 18),
#                             ('mestaruus', 17),
#                             ('kunto', 12),
#                             ('monipuolisuus', 11)],
#                 'Farthest': [('määrittely', -7),
#                              ('laa', -6),
#                              ('hyöty', -6),
#                              ('sähkö', -4)]},
#  'johto': {'Closest': [('markkina', 24),
#                        ('kauppa', 24),
#                        ('kannatus', 22),
#                        ('tietoturva', 22)],
#            'Farthest': [('juoma', -3),
#                         ('maku', -2),
#                         ('ominaisuudet', -1),
#                         ('valikoima', -1)]},
#  'joukkuepelaaminen': {'Closest': [('hauskuus', 38),
#                                    ('taso', 28),
#                                    ('kunto', 27),
#                                    ('arvostus', 24)],
#                        'Farthest': [('kaupunki', -3),
#                                     ('sähkö', -1),
#                                     ('aikomus', 1),
#                                     ('kasetti', 1)]},
#  'jousitus': {'Closest': [('ajettavuus', 71),
#                           ('moottori', 70),
#                           ('ajo-ominaisuudet', 66),
#                           ('akku', 33)],
#               'Farthest': [('kaupunki', -5),
#                            ('mielipide', -4),
#                            ('artisti', -4),
#                            ('haave', -3)]},
#  'juoma': {'Closest': [('maku', 55),
#                        ('annos', 45),
#                        ('hinta-laatusuhde', 19),
#                        ('kauppa', 14)],
#            'Farthest': [('arvot', -3),
#                         ('kannatus', -2),
#                         ('tarpeellisuus', -2),
#                         ('näkymät', -2)]},
#  'jämäkkyys': {'Closest': [('helppokäyttöisyys', 56),
#                            ('luotettavuus', 55),
#                            ('käyttömukavuus', 55),
#                            ('helppous', 49)],
#                'Farthest': [('kaupunki', -2),
#                             ('laa', -1),
#                             ('rahasiirto', 0),
#                             ('kasetti', 0)]},
#  'jääkiekko': {'Closest': [('hauskuus', 32),
#                            ('rap', 20),
#                            ('kunto', 17),
#                            ('monipuolisuus', 15)],
#                'Farthest': [('riski', -6),
#                             ('sopivuus', -4),
#                             ('tarpeellisuus', -4),
#                             ('hinta-laatusuhde', -2)]},
#  'kannattajakulttuuri': {'Closest': [('rap', 32),
#                                      ('mestaruus', 27),
#                                      ('markkina', 17),
#                                      ('status', 15)],
#                          'Farthest': [('sopivuus', -11),
#                                       ('informointi', -8),
#                                       ('tarpeellisuus', -5),
#                                       ('mielipide', -4)]},
#  'kannatus': {'Closest': [('arvostus', 30),
#                           ('mielipide', 23),
#                           ('arvot', 21),
#                           ('aikomus', 17)],
#               'Farthest': [('kasetti', -2),
#                            ('sähkö', -1),
#                            ('kaupunki', 0),
#                            ('korjaus', 0)]},
#  'kasetti': {'Closest': [('moottori', 29),
#                          ('rap', 18),
#                          ('tarkkuus', 17),
#                          ('jousitus', 17)],
#              'Farthest': [('informointi', -8),
#                           ('monipuolisuus', -7),
#                           ('tarpeellisuus', -7),
#                           ('arvot', -6)]},
#  'katsojamäärä': {'Closest': [('taso', 36),
#                               ('kattavuus', 27),
#                               ('kannatus', 26),
#                               ('arvostus', 26)],
#                   'Farthest': [('sähkö', -2),
#                                ('laa', -2),
#                                ('jousitus', 0),
#                                ('informointi', 0)]},
#  'kattavuus': {'Closest': [('laatu', 55),
#                            ('luotettavuus', 49),
#                            ('helppokäyttöisyys', 48),
#                            ('monipuolisuus', 45)],
#                'Farthest': [('laa', -8),
#                             ('juoma', 0),
#                             ('rap', 0),
#                             ('haave', 0)]},
#  'kauneus': {'Closest': [('hauskuus', 43),
#                          ('käyttömukavuus', 33),
#                          ('helppokäyttöisyys', 32),
#                          ('arvostus', 31)],
#              'Farthest': [('jousitus', -2),
#                           ('kasetti', 0),
#                           ('aikomus', 1),
#                           ('moottori', 1)]},
#  'kauppa': {'Closest': [('markkina', 38),
#                         ('rahasiirto', 27),
#                         ('luotonanto', 27),
#                         ('kaupunki', 24)],
#             'Farthest': [('ajo-ominaisuudet', -4),
#                          ('tarkkuus', -3),
#                          ('helppous', 0),
#                          ('hankaluus', 0)]},
#  'kaupunki': {'Closest': [('näkymät', 25),
#                           ('kauppa', 24),
#                           ('markkina', 18),
#                           ('esimerkki', 14)],
#               'Farthest': [('informointi', -10),
#                            ('ominaisuudet', -7),
#                            ('sopivuus', -7),
#                            ('luotettavuus', -6)]},
#  'kaupunkiajo': {'Closest': [('ajettavuus', 51),
#                              ('jousitus', 48),
#                              ('ajomukavuus', 48),
#                              ('ajo-ominaisuudet', 46)],
#                  'Farthest': [('laa', -3),
#                               ('mielipide', -2),
#                               ('haave', -1),
#                               ('kaupunki', 0)]},
#  'kehittyminen': {'Closest': [('määrittely', 46),
#                               ('arvostus', 40),
#                               ('laatu', 35),
#                               ('helppous', 31)],
#                   'Farthest': [('artisti', -7),
#                                ('juoma', -4),
#                                ('jousitus', -1),
#                                ('ostospäätös', 0)]},
#  'keskustelu': {'Closest': [('esimerkki', 28),
#                             ('mielipide', 25),
#                             ('informointi', 24),
#                             ('kauppa', 21)],
#                 'Farthest': [('sopivuus', -4),
#                              ('ajo-ominaisuudet', -3),
#                              ('ominaisuudet', -3),
#                              ('hinta-laatusuhde', -2)]},
#  'kesto': {'Closest': [('laatu', 30),
#                        ('tarkkuus', 28),
#                        ('kattavuus', 28),
#                        ('taso', 26)],
#            'Farthest': [('näkymät', -4),
#                         ('kauppa', -4),
#                         ('juoma', -3),
#                         ('sähkö', -3)]},
#  'kestävyys': {'Closest': [('käyttömukavuus', 69),
#                            ('laatu', 66),
#                            ('helppokäyttöisyys', 64),
#                            ('luotettavuus', 62)],
#                'Farthest': [('kaupunki', -1),
#                             ('rahasiirto', 0),
#                             ('haave', 0),
#                             ('laa', 1)]},
#  'keveys': {'Closest': [('käyttömukavuus', 67),
#                         ('helppokäyttöisyys', 66),
#                         ('ajomukavuus', 56),
#                         ('helppous', 54)],
#             'Farthest': [('mestaruus', 0),
#                          ('artisti', 0),
#                          ('aikomus', 1),
#                          ('rahasiirto', 2)]},
#  'kieli': {'Closest': [('taso', 22),
#                        ('hauskuus', 20),
#                        ('hankaluus', 16),
#                        ('arvostus', 16)],
#            'Farthest': [('informointi', -5),
#                         ('näkymät', -1),
#                         ('akku', 0),
#                         ('sähkö', 0)]},
#  'kielipolitiikka': {'Closest': [('huoltovarmuus', 29),
#                                  ('mielipide', 25),
#                                  ('kannatus', 23),
#                                  ('taso', 23)],
#                      'Farthest': [('juoma', 0),
#                                   ('tarkkuus', 0),
#                                   ('korjaus', 0),
#                                   ('ominaisuudet', 0)]},
#  'kiinnostavuus': {'Closest': [('arvostus', 66),
#                                ('laatu', 56),
#                                ('taso', 51),
#                                ('luotettavuus', 50)],
#                    'Farthest': [('sähkö', -2),
#                                 ('laa', -1),
#                                 ('juoma', 0),
#                                 ('jousitus', 0)]},
#  'kilpailukyky': {'Closest': [('huoltovarmuus', 67),
#                               ('arvostus', 47),
#                               ('luotettavuus', 46),
#                               ('markkina', 37)],
#                   'Farthest': [('kasetti', -4),
#                                ('rap', 0),
#                                ('ostospäätös', 0),
#                                ('artisti', 0)]},
#  'koko': {'Closest': [('ostospäätös', 12),
#                       ('markkina', 12),
#                       ('kunto', 11),
#                       ('arvot', 9)],
#           'Farthest': [('esimerkki', -3),
#                        ('mielipide', -2),
#                        ('näkymät', -2),
#                        ('tarpeellisuus', -1)]},
#  'kokoomus': {'Closest': [('kannatus', 59),
#                           ('arvot', 23),
#                           ('mielipide', 19),
#                           ('status', 15)],
#               'Farthest': [('laatu', -6),
#                            ('kasetti', -6),
#                            ('kunto', -4),
#                            ('valikoima', -4)]},
#  'kone': {'Closest': [('akku', 54),
#                       ('sähkö', 32),
#                       ('jousitus', 29),
#                       ('korjaus', 24)],
#           'Farthest': [('informointi', -5),
#                        ('riski', -4),
#                        ('määrittely', -3),
#                        ('ansio', -1)]},
#  'korjattavuus': {'Closest': [('käyttömukavuus', 61),
#                               ('helppokäyttöisyys', 56),
#                               ('laatu', 52),
#                               ('luotettavuus', 49)],
#                   'Farthest': [('haave', -4),
#                                ('annos', -2),
#                                ('artisti', -1),
#                                ('aikomus', 0)]},
#  'korjaus': {'Closest': [('sähkö', 33),
#                          ('kustomointi', 33),
#                          ('kunto', 28),
#                          ('moottori', 17)],
#              'Farthest': [('näkymät', -5),
#                           ('arvostus', -2),
#                           ('hauskuus', -2),
#                           ('maku', -1)]},
#  'kotimaa': {'Closest': [('kannatus', 27),
#                          ('rahasiirto', 14),
#                          ('kaupunki', 14),
#                          ('status', 7)],
#              'Farthest': [('ostospäätös', -8),
#                           ('ominaisuudet', -6),
#                           ('monipuolisuus', -5),
#                           ('helppous', -5)]},
#  'kotimaisuus': {'Closest': [('luotettavuus', 59),
#                              ('laatu', 57),
#                              ('helppokäyttöisyys', 57),
#                              ('käyttömukavuus', 48)],
#                  'Farthest': [('kaupunki', -3),
#                               ('mestaruus', 0),
#                               ('moottori', 1),
#                               ('ostospäätös', 1)]},
#  'kovalevy': {'Closest': [('kasetti', 47),
#                           ('moottori', 35),
#                           ('tarkkuus', 31),
#                           ('käyttömukavuus', 21)],
#               'Farthest': [('informointi', -4),
#                            ('näkymät', -4),
#                            ('monipuolisuus', -1),
#                            ('ansio', 0)]},
#  'kulutus': {'Closest': [('huoltovarmuus', 43),
#                          ('sähkö', 42),
#                          ('ajomukavuus', 42),
#                          ('moottori', 35)],
#              'Farthest': [('ostospäätös', -1),
#                           ('mielipide', 0),
#                           ('informointi', 0),
#                           ('artisti', 0)]},
#  'kun': {'Closest': [('ostospäätös', 23),
#                      ('hauskuus', 16),
#                      ('luotonanto', 14),
#                      ('hankaluus', 13)],
#          'Farthest': [('valikoima', -9),
#                       ('informointi', -9),
#                       ('määrittely', -8),
#                       ('hinta-laatusuhde', -7)]},
#  'kunto': {'Closest': [('laatu', 47),
#                        ('ajettavuus', 37),
#                        ('luotettavuus', 34),
#                        ('arvostus', 31)],
#            'Farthest': [('artisti', -1),
#                         ('kaupunki', 0),
#                         ('määrittely', 1),
#                         ('kasetti', 1)]},
#  'kuntoisuus': {'Closest': [('informointi', 35),
#                             ('kunto', 33),
#                             ('kattavuus', 32),
#                             ('luotettavuus', 31)],
#                 'Farthest': [('artisti', -1),
#                              ('maku', 0),
#                              ('kasetti', 0),
#                              ('akku', 1)]},
#  'kustomointi': {'Closest': [('korjaus', 33),
#                              ('helppokäyttöisyys', 32),
#                              ('ominaisuudet', 28),
#                              ('käyttömukavuus', 28)],
#                  'Farthest': [('arvot', -5),
#                               ('näkymät', -5),
#                               ('aikomus', -1),
#                               ('kaupunki', 0)]},
#  'kysymys': {'Closest': [('esimerkki', 44),
#                          ('hyöty', 33),
#                          ('määrittely', 29),
#                          ('hankaluus', 28)],
#              'Farthest': [('jousitus', -8),
#                           ('ajettavuus', -7),
#                           ('ajomukavuus', -6),
#                           ('hinta-laatusuhde', -4)]},
#  'käyt': {'Closest': [('neuvo', 21),
#                       ('kauppa', 13),
#                       ('ostospäätös', 10),
#                       ('kattavuus', 9)],
#           'Farthest': [('jousitus', -6),
#                        ('ajomukavuus', -6),
#                        ('huoltovarmuus', -6),
#                        ('ajettavuus', -6)]},
#  'käytettävyys': {'Closest': [('helppokäyttöisyys', 77),
#                               ('käyttömukavuus', 70),
#                               ('laatu', 68),
#                               ('luotettavuus', 66)],
#                   'Farthest': [('kaupunki', -5),
#                                ('mestaruus', 0),
#                                ('rap', 0),
#                                ('laa', 0)]},
#  'käyttö': {'Closest': [('tarpeellisuus', 33),
#                         ('käyttömukavuus', 33),
#                         ('helppokäyttöisyys', 32),
#                         ('kustomointi', 31)],
#             'Farthest': [('ostospäätös', -4),
#                          ('rap', -3),
#                          ('artisti', -3),
#                          ('mestaruus', -2)]},
#  'käyttöjärjestelmä': {'Closest': [('tietoturva', 52),
#                                    ('akku', 33),
#                                    ('ominaisuudet', 33),
#                                    ('tarkkuus', 23)],
#                        'Farthest': [('laa', 0),
#                                     ('informointi', 0),
#                                     ('näkymät', 0),
#                                     ('haave', 0)]},
#  'käyttökelpoisuus': {'Closest': [('laatu', 63),
#                                   ('tarpeellisuus', 60),
#                                   ('luotettavuus', 54),
#                                   ('käyttömukavuus', 52)],
#                       'Farthest': [('artisti', -1),
#                                    ('kaupunki', 0),
#                                    ('ostospäätös', 1),
#                                    ('kasetti', 1)]},
#  'käyttömukavuus': {'Closest': [('helppokäyttöisyys', 73),
#                                 ('ajomukavuus', 72),
#                                 ('laatu', 64),
#                                 ('luotettavuus', 60)],
#                     'Farthest': [('haave', -2),
#                                  ('mestaruus', -1),
#                                  ('rap', 0),
#                                  ('luotonanto', 0)]},
#  'käytös': {'Closest': [('arvostus', 35),
#                         ('hauskuus', 32),
#                         ('kunto', 31),
#                         ('maku', 24)],
#             'Farthest': [('sähkö', -4),
#                          ('näkymät', -2),
#                          ('akku', 0),
#                          ('kaupunki', 0)]},
#  'laa': {'Closest': [('näkymät', 11),
#                      ('juoma', 8),
#                      ('ostospäätös', 8),
#                      ('mielipide', 6)],
#          'Farthest': [('hinta-laatusuhde', -8),
#                       ('kattavuus', -8),
#                       ('akku', -7),
#                       ('helppous', -6)]},
#  'laatu': {'Closest': [('luotettavuus', 66),
#                        ('monipuolisuus', 64),
#                        ('käyttömukavuus', 64),
#                        ('helppokäyttöisyys', 61)],
#            'Farthest': [('mestaruus', -1),
#                         ('kaupunki', 0),
#                         ('laa', 0),
#                         ('artisti', 0)]},
#  'laitevaatimus': {'Closest': [('kustomointi', 38),
#                                ('kasetti', 36),
#                                ('moottori', 29),
#                                ('tarkkuus', 26)],
#                    'Farthest': [('arvot', -3),
#                                 ('kannatus', -3),
#                                 ('näkymät', -3),
#                                 ('informointi', -2)]},
#  'levy': {'Closest': [('kasetti', 47),
#                       ('artisti', 42),
#                       ('rap', 36),
#                       ('annos', 29)],
#           'Farthest': [('informointi', -6),
#                        ('riski', -5),
#                        ('tarpeellisuus', -3),
#                        ('hankaluus', -2)]},
#  'liikennekäyttäytyminen': {'Closest': [('ajomukavuus', 33),
#                                         ('ajo-ominaisuudet', 32),
#                                         ('huoltovarmuus', 27),
#                                         ('arvot', 26)],
#                             'Farthest': [('ostospäätös', -3),
#                                          ('kasetti', -2),
#                                          ('markkina', 0),
#                                          ('artisti', 0)]},
#  'liitokiekko': {'Closest': [('annos', 20),
#                              ('kunto', 19),
#                              ('hauskuus', 19),
#                              ('juoma', 17)],
#                  'Farthest': [('arvot', -6),
#                               ('hankaluus', -6),
#                               ('laa', -6),
#                               ('huoltovarmuus', -6)]},
#  'luotettavuus': {'Closest': [('helppokäyttöisyys', 68),
#                               ('laatu', 66),
#                               ('monipuolisuus', 63),
#                               ('käyttömukavuus', 60)],
#                   'Farthest': [('kaupunki', -6),
#                                ('annos', -1),
#                                ('mestaruus', 0),
#                                ('juoma', 0)]},
#  'luotonanto': {'Closest': [('rahasiirto', 40),
#                             ('markkina', 34),
#                             ('kauppa', 27),
#                             ('riski', 24)],
#                 'Farthest': [('ominaisuudet', -3),
#                              ('haave', -2),
#                              ('akku', 0),
#                              ('ajo-ominaisuudet', 0)]},
#  'läpinäkyvyys': {'Closest': [('luotettavuus', 61),
#                               ('monipuolisuus', 50),
#                               ('helppous', 46),
#                               ('laatu', 45)],
#                   'Farthest': [('rap', -6),
#                                ('annos', -6),
#                                ('mestaruus', -4),
#                                ('haave', -4)]},
#  'maku': {'Closest': [('juoma', 55),
#                       ('hinta-laatusuhde', 38),
#                       ('laatu', 35),
#                       ('kunto', 25)],
#           'Farthest': [('sähkö', -4),
#                        ('korjaus', -1),
#                        ('laa', -1),
#                        ('haave', -1)]},
#  'malli': {'Closest': [('jousitus', 21),
#                        ('moottori', 20),
#                        ('esimerkki', 17),
#                        ('ajo-ominaisuudet', 16)],
#            'Farthest': [('kunto', -1),
#                         ('helppous', 0),
#                         ('informointi', 0),
#                         ('riski', 0)]},
#  'markkina': {'Closest': [('kauppa', 38),
#                           ('luotonanto', 34),
#                           ('rahasiirto', 27),
#                           ('huoltovarmuus', 27)],
#               'Farthest': [('jousitus', 0),
#                            ('laa', 0),
#                            ('annos', 0),
#                            ('akku', 1)]},
#  'menestys': {'Closest': [('arvostus', 47),
#                           ('monipuolisuus', 34),
#                           ('taso', 32),
#                           ('hauskuus', 30)],
#               'Farthest': [('akku', -3),
#                            ('laa', -3),
#                            ('jousitus', -1),
#                            ('korjaus', 0)]},
#  'merkki': {'Closest': [('esimerkki', 44),
#                         ('hankaluus', 25),
#                         ('hyöty', 19),
#                         ('arvostus', 16)],
# ...
#               'Farthest': [('sähkö', -3),
#                            ('arvot', 1),
#                            ('riski', 2),
#                            ('juoma', 3)]},
#  'suorituskyky': {'Closest': [('käyttömukavuus', 73),
#                               ('ajomukavuus', 66),
#                               ('tarkkuus', 64),
#                               ('helppokäyttöisyys', 64)],
#                   'Farthest': [('kaupunki', -2),
#                                ('ostospäätös', -1),
#                                ('haave', -1),
#                                ('rap', 0)]},
#  'suosio': {'Closest': [('arvostus', 51),
#                         ('kannatus', 42),
#                         ('markkina', 32),
#                         ('helppous', 23)],
#             'Farthest': [('jousitus', -1),
#                          ('sähkö', -1),
#                          ('informointi', 0),
#                          ('akku', 2)]},
#  'suosittelu': {'Closest': [('tietoturva', 30),
#                             ('helppokäyttöisyys', 28),
#                             ('status', 27),
#                             ('luotettavuus', 24)],
#                 'Farthest': [('kaupunki', -6),
#                              ('akku', -4),
#                              ('haave', -4),
#                              ('moottori', -2)]},
#  'sympaattisuus': {'Closest': [('hauskuus', 50),
#                                ('arvostus', 39),
#                                ('helppokäyttöisyys', 36),
#                                ('helppous', 35)],
#                    'Farthest': [('mestaruus', -3),
#                                 ('markkina', -2),
#                                 ('laa', -2),
#                                 ('akku', 0)]},
#  'sähkö': {'Closest': [('huoltovarmuus', 35),
#                        ('korjaus', 33),
#                        ('moottori', 26),
#                        ('akku', 25)],
#            'Farthest': [('hinta-laatusuhde', -4),
#                         ('maku', -4),
#                         ('aikomus', -2),
#                         ('ostospäätös', -2)]},
#  'taistelulajit': {'Closest': [('hauskuus', 24),
#                                ('rap', 22),
#                                ('ominaisuudet', 19),
#                                ('juoma', 15)],
#                    'Farthest': [('tietoturva', -11),
#                                 ('tarpeellisuus', -8),
#                                 ('huoltovarmuus', -8),
#                                 ('aikomus', -7)]},
#  'takuu': {'Closest': [('korjaus', 30),
#                        ('ajomukavuus', 26),
#                        ('kasetti', 24),
#                        ('käyttömukavuus', 24)],
#            'Farthest': [('kaupunki', -3),
#                         ('laa', -3),
#                         ('aikomus', 0),
#                         ('ansio', 0)]},
#  'tarkkuus': {'Closest': [('käyttömukavuus', 56),
#                           ('laatu', 55),
#                           ('helppokäyttöisyys', 49),
#                           ('luotettavuus', 44)],
#               'Farthest': [('juoma', -4),
#                            ('laa', -3),
#                            ('kauppa', -3),
#                            ('aikomus', -2)]},
#  'tarpeellisuus': {'Closest': [('laatu', 45),
#                                ('luotettavuus', 43),
#                                ('määrittely', 42),
#                                ('monipuolisuus', 40)],
#                    'Farthest': [('haave', -4),
#                                 ('artisti', -3),
#                                 ('juoma', -2),
#                                 ('sähkö', -2)]},
#  'taso': {'Closest': [('laatu', 56),
#                       ('arvostus', 53),
#                       ('monipuolisuus', 40),
#                       ('kunto', 40)],
#           'Farthest': [('kaupunki', 0),
#                        ('haave', 1),
#                        ('akku', 2),
#                        ('kasetti', 2)]},
#  'tehokkuus': {'Closest': [('luotettavuus', 77),
#                            ('laatu', 69),
#                            ('helppokäyttöisyys', 67),
#                            ('käyttömukavuus', 63)],
#                'Farthest': [('kasetti', -6),
#                             ('haave', -4),
#                             ('artisti', -2),
#                             ('mestaruus', -1)]},
#  'tehokuus': {'Closest': [('tarpeellisuus', 28),
#                           ('arvot', 25),
#                           ('hankaluus', 21),
#                           ('ostospäätös', 21)],
#               'Farthest': [('näkymät', -3),
#                            ('hinta-laatusuhde', -2),
#                            ('korjaus', -2),
#                            ('kauppa', -2)]},
#  'tekniikka': {'Closest': [('käyttömukavuus', 38),
#                            ('ominaisuudet', 36),
#                            ('helppokäyttöisyys', 35),
#                            ('ajo-ominaisuudet', 34)],
#                'Farthest': [('laa', -4),
#                             ('kaupunki', 0),
#                             ('kannatus', 0),
#                             ('näkymät', 2)]},
#  'tekninen': {'Closest': [('luotettavuus', 35),
#                           ('helppokäyttöisyys', 35),
#                           ('laatu', 30),
#                           ('monipuolisuus', 28)],
#               'Farthest': [('annos', -1),
#                            ('kannatus', 0),
#                            ('ostospäätös', 0),
#                            ('näkymät', 0)]},
#  'tekopyhyys': {'Closest': [('arvostus', 37),
#                             ('hankaluus', 30),
#                             ('arvot', 27),
#                             ('kannatus', 26)],
#                 'Farthest': [('korjaus', -4),
#                              ('hinta-laatusuhde', -2),
#                              ('kasetti', -1),
#                              ('sopivuus', -1)]},
#  'tieto': {'Closest': [('hyöty', 36),
#                        ('informointi', 33),
#                        ('yleiskuva', 32),
#                        ('luotettavuus', 29)],
#            'Farthest': [('ajo-ominaisuudet', -5),
#                         ('näkymät', -5),
#                         ('jousitus', -4),
#                         ('laa', -3)]},
#  'tietoturva': {'Closest': [('helppokäyttöisyys', 43),
#                             ('luotettavuus', 39),
#                             ('käyttömukavuus', 35),
#                             ('kattavuus', 33)],
#                 'Farthest': [('kaupunki', -4),
#                              ('haave', -2),
#                              ('aikomus', -1),
#                              ('mestaruus', -1)]},
#  'toiminta': {'Closest': [('arvostus', 30),
#                           ('informointi', 28),
#                           ('hauskuus', 27),
#                           ('luotettavuus', 26)],
#               'Farthest': [('laa', -5),
#                            ('artisti', -3),
#                            ('näkymät', 0),
#                            ('juoma', 2)]},
#  'toimintakyky': {'Closest': [('kunto', 56),
#                               ('luotettavuus', 41),
#                               ('arvostus', 36),
#                               ('monipuolisuus', 32)],
#                   'Farthest': [('kasetti', -7),
#                                ('laa', -7),
#                                ('artisti', -4),
#                                ('mestaruus', 0)]},
#  'toimivuus': {'Closest': [('helppokäyttöisyys', 69),
#                            ('luotettavuus', 67),
#                            ('laatu', 64),
#                            ('käyttömukavuus', 63)],
#                'Farthest': [('haave', -4),
#                             ('kaupunki', -1),
#                             ('rap', 0),
#                             ('ostospäätös', 0)]},
#  'tuote': {'Closest': [('kauppa', 27),
#                        ('juoma', 25),
#                        ('kustomointi', 24),
#                        ('kasetti', 22)],
#            'Farthest': [('aikomus', -4),
#                         ('kannatus', -3),
#                         ('ansio', -1),
#                         ('laa', -1)]},
#  'tuotevalikoima': {'Closest': [('valikoima', 59),
#                                 ('helppokäyttöisyys', 40),
#                                 ('laatu', 37),
#                                 ('monipuolisuus', 36)],
#                     'Farthest': [('haave', -5),
#                                  ('artisti', -2),
#                                  ('mestaruus', -1),
#                                  ('status', 0)]},
#  'tuttuus': {'Closest': [('hauskuus', 49),
#                          ('helppous', 44),
#                          ('hankaluus', 43),
#                          ('helppokäyttöisyys', 43)],
#              'Farthest': [('mestaruus', -3),
#                           ('kasetti', -2),
#                           ('rahasiirto', 0),
#                           ('sähkö', 0)]},
#  'tyyli': {'Closest': [('hauskuus', 39),
#                        ('maku', 37),
#                        ('rap', 33),
#                        ('käyttömukavuus', 32)],
#            'Farthest': [('riski', -2),
#                         ('mestaruus', -1),
#                         ('rahasiirto', 0),
#                         ('informointi', 0)]},
#  'ulkonäkö': {'Closest': [('käyttömukavuus', 55),
#                           ('laatu', 54),
#                           ('helppokäyttöisyys', 48),
#                           ('maku', 47)],
#               'Farthest': [('sähkö', -2),
#                            ('laa', -1),
#                            ('rahasiirto', 0),
#                            ('kaupunki', 3)]},
#  'urheilu': {'Closest': [('kunto', 26),
#                          ('hauskuus', 26),
#                          ('mestaruus', 24),
#                          ('rap', 22)],
#              'Farthest': [('ostospäätös', -5),
#                           ('annos', -2),
#                           ('hinta-laatusuhde', -1),
#                           ('määrittely', -1)]},
#  'vahvuus': {'Closest': [('helppokäyttöisyys', 46),
#                          ('arvostus', 45),
#                          ('luotettavuus', 44),
#                          ('laatu', 42)],
#              'Farthest': [('laa', -2),
#                           ('sähkö', -1),
#                           ('akku', 0),
#                           ('korjaus', 0)]},
#  'vaihtoehdot': {'Closest': [('ominaisuudet', 33),
#                              ('arvot', 26),
#                              ('näkymät', 16),
#                              ('määrittely', 12)],
#                  'Farthest': [('hauskuus', -4),
#                               ('mestaruus', -3),
#                               ('aikomus', -2),
#                               ('markkina', -2)]},
#  'vaikeus': {'Closest': [('hankaluus', 67),
#                          ('hauskuus', 41),
#                          ('tarpeellisuus', 40),
#                          ('määrittely', 37)],
#              'Farthest': [('sähkö', -3),
#                           ('kasetti', -3),
#                           ('näkymät', -3),
#                           ('rap', -2)]},
#  'vaikutus': {'Closest': [('hyöty', 46),
#                           ('arvostus', 36),
#                           ('taso', 32),
#                           ('ansio', 31)],
#               'Farthest': [('akku', 0),
#                            ('jousitus', 0),
#                            ('rap', 0),
#                            ('kasetti', 0)]},
#  'vakiovarusteet': {'Closest': [('jousitus', 52),
#                                 ('moottori', 48),
#                                 ('akku', 37),
#                                 ('ajo-ominaisuudet', 36)],
#                     'Farthest': [('ostospäätös', -9),
#                                  ('kannatus', -8),
#                                  ('maku', -6),
#                                  ('arvostus', -5)]},
#  'valikoima': {'Closest': [('monipuolisuus', 27),
#                            ('kattavuus', 27),
#                            ('helppous', 26),
#                            ('laatu', 26)],
#                'Farthest': [('laa', -3),
#                             ('haave', -3),
#                             ('arvot', -2),
#                             ('artisti', -1)]},
#  'valta': {'Closest': [('arvot', 30),
#                        ('arvostus', 30),
#                        ('kannatus', 26),
#                        ('mielipide', 25)],
#            'Farthest': [('laa', -4),
#                         ('hinta-laatusuhde', -3),
#                         ('annos', -1),
#                         ('akku', 0)]},
#  'varaosat': {'Closest': [('korjaus', 47),
#                           ('sähkö', 27),
#                           ('jousitus', 26),
#                           ('ominaisuudet', 22)],
#               'Farthest': [('laa', -6),
#                            ('aikomus', -5),
#                            ('annos', -5),
#                            ('ostospäätös', -4)]},
#  'varuste': {'Closest': [('jousitus', 37),
#                          ('ajomukavuus', 36),
#                          ('ajo-ominaisuudet', 32),
#                          ('käyttömukavuus', 30)],
#              'Farthest': [('arvot', -4),
#                           ('rap', 0),
#                           ('luotonanto', 0),
#                           ('kannatus', 1)]},
#  'varustelu': {'Closest': [('ajomukavuus', 52),
#                            ('jousitus', 50),
#                            ('ajo-ominaisuudet', 49),
#                            ('käyttömukavuus', 47)],
#                'Farthest': [('laa', -3),
#                             ('mestaruus', -1),
#                             ('mielipide', -1),
#                             ('ostospäätös', -1)]},
#  'varustetaso': {'Closest': [('käyttömukavuus', 37),
#                              ('ajomukavuus', 37),
#                              ('ajo-ominaisuudet', 35),
#                              ('kunto', 34)],
#                  'Farthest': [('mielipide', -2),
#                               ('haave', 2),
#                               ('kannatus', 3),
#                               ('aikomus', 4)]},
#  'viihde': {'Closest': [('rap', 28),
#                         ('hauskuus', 27),
#                         ('monipuolisuus', 23),
#                         ('valikoima', 22)],
#             'Farthest': [('aikomus', -1),
#                          ('hinta-laatusuhde', -1),
#                          ('määrittely', -1),
#                          ('korjaus', -1)]},
#  'voitto': {'Closest': [('ansio', 31),
#                         ('hyöty', 24),
#                         ('taso', 24),
#                         ('rahasiirto', 21)],
#             'Farthest': [('laa', -4),
#                          ('sopivuus', -4),
#                          ('akku', -1),
#                          ('ominaisuudet', -1)]},
#  'yhteensopivuus': {'Closest': [('helppokäyttöisyys', 61),
#                                 ('käyttömukavuus', 53),
#                                 ('luotettavuus', 51),
#                                 ('tietoturva', 49)],
#                     'Farthest': [('artisti', -5),
#                                  ('rap', -3),
#                                  ('annos', -2),
#                                  ('haave', -2)]},
#  'yleine': {'Closest': [('ammattilaine', 39),
#                         ('ostospäätös', 28),
#                         ('neuvo', 23),
#                         ('rap', 22)],
#             'Farthest': [('näkymät', -5),
#                          ('luotonanto', -4),
#                          ('helppokäyttöisyys', -4),
#                          ('kattavuus', -4)]},
#  'yleinen': {'Closest': [('hankaluus', 36),
#                          ('status', 32),
#                          ('arvostus', 30),
#                          ('monipuolisuus', 29)],
#              'Farthest': [('akku', -6),
#                           ('kaupunki', -2),
#                           ('annos', -2),
#                           ('artisti', -1)]},
#  'yleiskuva': {'Closest': [('esimerkki', 32),
#                            ('käytettävyys', 30),
#                            ('määrittely', 29)],
#                'Farthest': [('sähkö', -1),
#                             ('mestaruus', 0),
#                             ('kasetti', 0),
#                             ('luotonanto', 0)]}}
#
# Most similar aspects:  ['käytettävyys', 'helppokäyttöisyys', 77]
# Least similar aspects:  ['ennustus', 'helppokäyttöisyys', -13]

# %% [markdown]
# ###RESULT ANALYSIS:
# Now we have found out which aspects found in our dataset are most and least similar to each other on vector level. From the results we could deduct that 'tuttuus' or familiarity with a product is related with feelings of fun and easy, or that 'toimivuus' or functionality is close to ease of use, reliability, quality and usability. According to this analysis, most similar aspects are 'käytettävyys' and 'helppokäyttöisyys' that have score of 77 percent similarity between the vectors, but even they are not synonyms.
#
# The pitfall of this analysis is that the similarity of vectors doesn't say anything on the synonymy of the words but only on their vectors' closeness. Thus, we also get antonyms or seemingly unrelated words in the close hits. This shows that word2vec alone can't be used to determine if two words are synonyms.

# %% [markdown]
# # 2. USING FinnWordNet
#
# > As word2vec looks at words from pure vector similarity aspect without regarding grammar, I wanted to try out also another option. So, I'm trying to use the Wordnet's synsets to find synonyms. Let's see how it goes...

# %%
# reading from synsets
synset_matrix =[]
with open('fiwn-synsets-extra.tsv',encoding= 'utf-8') as tsv:
    tsvreader = csv.reader(tsv, delimiter= '\t')   
    for line in tsvreader:
        synset = []
        #print(line)
        syns = line[2].split("|") #synonyms are separated by '|' in the col2 of the tsv file
        for i in range(len(syns)):
            word = syns[i].split('<')[0] # if there is XML behind the word f.ex. <broader>
            synset.append(word.strip())
        synset_matrix.append(synset)
#pprint(synset_matrix[:10])

def findInSynset(word):
    for i in range(len(synset_matrix)):
        #print(synset_matrix[i])
        ss = synset_matrix[i]
        #for j in range(len(synset_matrix[i])):
        if word == ss[0]:
            #print("Found a hit in synsets:\n word: " ,word," synset:", ss )
            return [True,ss]
# test
test = findInSynset('laatu')
print(test)
# Out:
# [True, ['laatu', 'luokka', 'taso']]

# %%
aspects = asp_uniq_set #from before
print("Unique aspects: ", len(aspects))
syn_aspects = []
nonsyn_aspects =[]
syn_as = []
for asp in aspects:
    value, synset = None, []
    check = findInSynset(asp)
    if check is not None:
        value = check[0]
        synset = check[1]
        if value:
            syn_as.append(asp)
            #print(synset)
            for syn in synset:
                if syn in aspects: 
                    if syn != asp:
                        syn_as.append(syn)
        if len(syn_as) >1:
            syn_aspects.append(syn_as)
        else:
            nonsyn_aspects.append(syn_as[0])
        syn_as = []
    else:
        nonsyn_aspects.append(asp)
print()
print("Synonymous aspects in the data: ",len(syn_aspects), '\n')
for item in syn_aspects:
    print(item)
print()
print("Aspects  without synonyms in the data:", len(nonsyn_aspects),'\n')
print(nonsyn_aspects)
# Out:
# Unique aspects:  227
#
# Synonymous aspects in the data:  14
#
# ['hankaluus', 'ongelma', 'vaikeus']
# ['laatu', 'taso']
# ['sopivuus', 'yhteensopivuus']
# ['ajoneuvo', 'auto']
# ['käytettävyys', 'saatavuus']
# ['mielenkiinto', 'mielenkiintoisuus']
# ['kysymys', 'ongelma']
# ['asiantuntemus', 'osaaminen']
# ['huolto', 'korjaus']
# ['ennuste', 'ennustus']
# ['arvostelu', 'korjaus']
# ['tehokkuus', 'vaikutus']
# ['suorituskyky', 'toiminta']
# ['hyvyys', 'hyvä']
#
# Aspects  without synonyms in the data: 213
#
# ['aikomus', 'status', 'monipuolisuus', 'helppous', 'hinta-laatusuhde', 'akku', 'ajo-ominaisuudet', 'määrittely', 'moottori', 'ansio', 'mestaruus', 'rahasiirto', 'luotettavuus', 'kaupunki', 'arvot', 'juoma', 'kannatus', 'arvostus', 'tarkkuus', 'kunto', 'mielipide', 'korjaus', 'ajo-ominaisuus', 'jousitus', 'rap', 'tietoturva', 'ostospäätös', 'maku', 'sähkö', 'ominaisuudet', 'markkina', 'kasetti', 'laa', 'valikoima', 'luotonanto', 'informointi', 'tarpeellisuus', 'kustomointi', 'käyttömukavuus', 'annos', 'artisti', 'hyöty', 'esimerkki', 'näkymät', 'hauskuus', 'helppokäyttöisyys', 'kauppa', 'ajomukavuus', 'huoltovarmuus', 'kattavuus', 'taso', 'riski', 'haave', 'ajettavuus', 'yleiskuva', 'pelaaminen', 'suoritus', 'varustetaso', 'yleine', 'kieli', 'app', 'yhteensopivuus', 'arvio', 'toimintakyky', 'bensankulutus', 'asiakaspalvelu', 'asema', 'kesto', 'korjattavuus', 'auto', 'toiminta', 'raha', 'jääkiekko', 'takuu', 'muotoilu', 'neliveto', 'johto', 'tyyli', 'gpu', 'ennustus', 'viihde', 'ulkonäkö', 'helppo', 'tehokuus', 'asennus', 'katsojamäärä', 'kotimaa', 'mukavuudet', 'vaihtoehdot', 'perusteet', 'kauneus', 'ajokokemus', 'merkki', 'valta', 'levy', 'esto', 'nautinto', 'läpinäkyvyys', 'esitys', 'tekninen', 'saatavuus', 'tieto', 'neuvo', 'keveys', 'kokoomus', 'kannattajakulttuuri', 'keskustelu', 'hiiri', 'kovalevy', 'ohjelma', 'kehittyminen', 'vahvuus', 'hyvä', 'edistyneisyys', 'ruokakauppa', 'kun', 'liikennekäyttäytyminen', 'ikä', 'käyttö', 'hint', 'mielikuva', 'kiinnostavuus', 'golf', 'hieno', 'jämäkkyys', 'hohto', 'käytös', 'pelaaja', 'varaosat', 'sarjataso', 'ominaisuus', 'paino', 'taistelulajit', 'jakelu', 'ergonomia', 'design', 'sijoitus', 'arvo', 'pallo', 'pyöräily', 'pyöräilyä', 'astiat', 'soveltuvuus', 'osaaminen', 'hygienia', 'hinta', 'mielenkiintoisuus', 'suosittelu', 'joukkuepelaaminen', 'ohje', 'coctail', 'määrä', 'pyöräilyt', 'voitto', 'vaikeus', 'kielipolitiikka', 'ennakoitavuus', 'kone', 'nopeus', 'yleinen', 'kotimaisuus', 'hakukone', 'blogi', 'tuotevalikoima', 'alkuperä', 'politiikka', 'aika', 'myynti', 'näkemys', 'budjetointi', 'kuntoisuus', 'bonukset', 'mukavuus', 'käyttöjärjestelmä', 'tuttuus', 'iso', 'riskitaso', 'menestys', 'toimivuus', 'kilpailukyky', 'ammattilaine', 'malli', 'arvolisävero', 'koko', 'käyt', 'varustelu', 'ongelma', 'norjalaisuus', 'vaikutus', 'vakiovarusteet', 'sympaattisuus', 'arvostelut', 'kaupunkiajo', 'laitevaatimus', 'kulutus', 'apple', 'tuote', 'tekniikka', 'kestävyys', 'varuste', 'alusta', 'urheilu', 'käyttökelpoisuus', 'tekopyhyys', 'suosio', 'analyysi', 'jalkapallo', 'epäsäännöllisyys', 'harrastus', 'liitokiekko', 'facebook', 'hienoudet', 'nykyaikaisuus']

# %% [markdown]
# RESULT ANALYSIS:
#
# Above shows that some synonyms were found within the aspects, but not that many. Some of the synonyms found this way are logical, but others would need a closer look. For example, 'arvostelu' and 'korjaus' do not feel very synonymous, which raises the question of how suitable the synsets of FinnWordNet are for this kind of task. The semantic connection between the supposed synonyms would have to be studied to determine the final judgement on whether, in this case, they really are synonyms or not. I also tried using Voikko and a few other resources for this purpose.
#
# All in all, I was positively surprised that I was able to find some synonyms in the data as my hypothesis was the opposite. Why? Because the annotation did not limit the choice of aspect in anyway or give suggestions, the annotators selected whatever word they thought of, or none, resulting in wide range of words with single instance in the data.

# %% [markdown]
# # Milestone III: : automatic sentiment detection (mandatory)
#
# Each project group will create an automatic sentiment detection system using the annotated data and a text classification method as taught on the course (for example a bag-of-words SVM, but you are free to choose any other classification method as well).
#
# The task setting is as follows: given target texts and their right and left contexts, assign each context to one of the sentiment classes (positive, negative, etc.). For example:
#
# Left context Target Right context Sentiment “Minun mielestäni” “Nordea” “on ihan hyvä pankki.” positive “Siirryin” “Op:sta” “pois sössimisten vuoksi.” negative
#
# The sentiment detection systems will be evaluated on a held-out portion of the annotated data in terms of their accuracy.
#
# We will provide each project group with data for training and evaluating the sentiment detection methods in a simple TSV format.

# %%
# preprocessing the data
def collect_sentences(raw_data):
    sentences =[]
    for item in raw_data:
        left = item['left context']
        right = item['right context']
        target = item['target']
        sentence_with_context = left+' '+ target+ ' '+ right
        #print(sentence)
        label = item['judgement']
        sentences.append([label,target, sentence_with_context])
    return sentences

# %%
train_sents = collect_sentences(train_data)
print(train_sents[0])
# Out:
# ['positive', 'Green gasin', 'Metallinen vai muovinen ? Varustelekasta ( sekä tietty ihan airsoft liikkeistäkin ) saa Cybergun APS3 - kaasua joka on ihan OK lähestulkoon kaikille kaasupistooleille . Hieman tehokkaampaa kuin 134a muttei kuitenkaan esim.  Green gasin  veroista .']

# %%
## same for dev and test data
dev_sents = collect_sentences(dev_data)
print(dev_sents[0])
print()
test_sents = collect_sentences(test_data)
print(test_sents[0])
# Out:
# ['positive', 'Endomondoa', 'Treenipäivyrihän tuo on käytännössä , punttauksen puolellahan siitä on paljonkin hyötyä . Sports Tracker toimii erittäin paskasti Androidilla , kaatuu aina treenin lopussa . Suosittelen  Endomondoa  Android-käyttäjille .']
#
# [[['positive', 0.5], ['neutral', 0.5]], 'Fordin', 'Tämä . BMW provosoi tarpeettomiin ohituksiin . Liikennevaloissa lähtiessäkin on usein yhden hengen kiihdytyskisat pystyssä .  Fordin  ratissa ei tarvitse katsella tätä , vaikka ajotyyli ja nopeus on samoja . Onko tämä sitä kateutta ?']

# %%
# gathering texts and labels to lists
train_texts = [item[2] for item in train_sents]
train_labels =  [item[0] for item in train_sents]
print("No of train texts: ", len(train_texts))
print("No of train labels: ", len(train_labels))
for label,text in list(zip(train_labels,train_texts))[:20]:
    print(label,text[:50]+"...")
# Out:
# No of train texts:  386
# No of train labels:  386
# positive Metallinen vai muovinen ? Varustelekasta ( sekä ti...
# negative Kuva liittyy , siinä luukkulamputon  AE86  , joka ...
# negative Nyymit hoi ! Tarvitsisin hieman apua . Koneen virk...
# positive Olin viime viikolla Iso-Roban  Yamato Sushi -mesta...
# positive  Mai Mai  on mahtava rentoutumiseen . Oma suosikki...
# positive Hyvä tarkkuuspiippu parantaa tarkkuutta aivan silm...
# neutral Oletko ollut tyytyväinen shinobiin ? Mulle tulee o...
# negative  Deltacon  näppäimistöt tuppaa olemaan heikkolaatu...
# positive Jos sinulla on muutama satku säästöissä , niin uno...
# negative En tiedä näitten  Thinkpadien  hinnoittelusta mutt...
# positive  Macho  hinta-laatusuhteeltan paras valinta , kell...
# negative Kokeilin Minttiä n. viikon ajan . Vähän väliä tuli...
# neutral Onko kukaan törmännyt kuvan tai muiden android-puh...
# neutral Kyseinen auto taitaa olla  Mursu  . Niissä on nyky...
# neutral Eikös  Nordnetissä  ole kaupankäyntikulut aina 8e/...
# neutral Huomenna jatkuu  Ässiä  vastaan Areenalla . Niemi ...
# positive On olemassa myös hyvin toimivia portaattomia laati...
# negative Mielummin halpa Toyota Corolla kuin halpa  bemari ...
# negative Ja onhan noita iäkkäämpien herrojen jäävuoroja mis...
# neutral Eikös  outotec  ole kärsinyt mm. Venäjän isottelus...

# %%
#same for dev data 
dev_texts = [item[2] for item in dev_sents]
dev_labels =  [item[0] for item in dev_sents]
print("No of dev texts: ", len(dev_texts))
print("No of dev labels: ", len(dev_labels))
#and test
test_texts = [item[2] for item in test_sents]
test_labels =  [item[0] for item in test_sents]
# Out:
# No of dev texts:  166
# No of dev labels:  166

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer=CountVectorizer(max_features=100000,binary=True,ngram_range=(1,1))
feature_matrix_train=vectorizer.fit_transform(train_texts)
print("shape of train f-matrix =",feature_matrix_train.shape)
# Out:
# shape of train f-matrix = (386, 5286)

# %%
#print(feature_matrix)

# %%
#pprint(vectorizer.get_feature_names()[:1000])

# %%
feature_matrix_dev=vectorizer.transform(dev_texts)
print("shape of dev f-matrix =",feature_matrix_dev.shape)
# Out:
# shape of dev f-matrix = (166, 5286)

# %%
import sklearn.svm
classifier=sklearn.svm.LinearSVC(C=0.03,verbose=1)
classifier.fit(feature_matrix_train, train_labels)
# Out:
# [LibLinear]
# LinearSVC(C=0.03, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=1)

# %%
print("DEV",classifier.score(feature_matrix_dev, dev_labels))
print("TRAIN",classifier.score(feature_matrix_train, train_labels))
# Out:
# DEV 0.536144578313253
# TRAIN 0.9974093264248705

# %%
import sklearn.metrics
predictions_dev=classifier.predict(feature_matrix_dev)
print(predictions_dev)
print(sklearn.metrics.confusion_matrix(dev_labels,predictions_dev))
print(sklearn.metrics.accuracy_score(dev_labels,predictions_dev))
# Out:
# ['positive' 'positive' 'positive' 'neutral' 'negative' 'positive'
#  'neutral' 'positive' 'negative' 'positive' 'neutral' 'neutral' 'neutral'
#  'negative' 'positive' 'positive' 'neutral' 'positive' 'neutral' 'neutral'
#  'positive' 'positive' 'neutral' 'positive' 'neutral' 'negative'
#  'positive' 'positive' 'neutral' 'neutral' 'neutral' 'neutral' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'negative' 'neutral' 'positive' 'positive' 'positive' 'positive'
#  'neutral' 'positive' 'positive' 'positive' 'neutral' 'neutral' 'positive'
#  'positive' 'positive' 'positive' 'neutral' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'negative' 'positive' 'neutral'
#  'positive' 'positive' 'neutral' 'positive' 'neutral' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'neutral' 'positive'
#  'negative' 'positive' 'positive' 'neutral' 'positive' 'neutral'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'neutral' 'positive' 'positive' 'neutral' 'negative' 'positive'
#  'positive' 'neutral' 'neutral' 'positive' 'neutral' 'positive' 'positive'
#  'neutral' 'positive' 'neutral' 'neutral' 'positive' 'neutral' 'neutral'
#  'neutral' 'neutral' 'positive' 'positive' 'neutral' 'positive' 'positive'
#  'positive' 'neutral' 'neutral' 'positive' 'positive' 'positive'
#  'positive' 'neutral' 'positive' 'positive' 'positive' 'positive'
#  'neutral' 'positive' 'neutral' 'neutral' 'positive' 'neutral' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'neutral' 'neutral'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'neutral'
#  'positive' 'positive' 'positive' 'neutral' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'neutral' 'positive']
# [[ 3 10 21]
#  [ 3 25 26]
#  [ 2 15 61]]
# 0.536144578313253

# %%
# The model is not very good, but let's save it anyway and make predictions on the test data to see some results
import pickle

with open("saved_model.pickle","wb") as f:
    pickle.dump((classifier,vectorizer),f)

# %%
with open("saved_model.pickle","rb") as f:    
    classifier_loaded,vectorizer_loaded=pickle.load(f)

feature_matrix_dev_loaded=vectorizer_loaded.transform(dev_texts)
print("DEV - loaded (should match the score above)",classifier_loaded.score(feature_matrix_dev, dev_labels))
# Out:
# DEV - loaded (should match the score above) 0.536144578313253

# %%
feature_matrix_test = vectorizer_loaded.transform(test_texts)
predictions_test = classifier_loaded.predict(feature_matrix_test)
#print(predictions_test[:10])
#print(test_labels[:10])

for item in test_data:
    judg = item['judgement']
    if(type(judg) == str):
        item['judgement'] = [item['judgement'],predictions_test[test_data.index(item)]]
    else:
        item['judgement'].append([predictions_test[test_data.index(item)]])
    #print(item['judgement'])

# %% [markdown]
# Let's test the saved model on the test set we prepared before to see if it can determine a final sentiment for the cases that had several.

# %%
for item in test_data:   
    print("Target word: ", item['target'])
    print("sentence: ", item['left context']+item['target']+item['right context'])
    print("predicted: ", item['judgement'][len(item['judgement'])-1], ", original sentiment labels: ", item['judgement'][:len(item['judgement'])-1])
    print('------------------------------------------------------')
# Out:
# Target word:  Fordin
# sentence:  Tämä . BMW provosoi tarpeettomiin ohituksiin . Liikennevaloissa lähtiessäkin on usein yhden hengen kiihdytyskisat pystyssä . Fordin ratissa ei tarvitse katsella tätä , vaikka ajotyyli ja nopeus on samoja . Onko tämä sitä kateutta ?
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  skoda octavia rs : t
# sentence:  Vaikka uudet skoda octavia rs : t ovat ihan mukavan näköisiä , on silti aika absurdia sanoa semmoisen olevan unelma - auto . Noh , kukin tavallaan .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  subarussa
# sentence:  No audissa on 142mm ja subarussa 144mm ? Ja onhan tossa normaalissa kutosessa pitkä ja pehmeä jousitus . Toteutettu vielä monitukivarsilla mäcpearsonin sijasta . Varmasti kokonaisuudessaan antaa paremmat kyydit mitä tollanen imppu .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Lagunan
# sentence:  Ei kai se Lagunan hihnanvaihto nyt niin kallis voi olla , vai meneekö muutakin uusiksi samalla ?
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Buzz SS
# sentence:  Vähän kaikenlaista , tällä hetkellä oon heitelly kalevan miekkaa , bossia , mambaa ja beastia . Buzz SS toimii mun midikiekkona . Kaikki kiekot midikiekosta drivereihin lentää kuitenkin melkee yhtä pitkälle , 50-70m . Heittelin ennen leopardia driverinä mutta oon niitä kadottanu 2 ja ei oo viittiny ostaa kolmatta . Jep , niitä on tullu katottua mutta jotenkin on vaan niin hankalaa omaksua niitä heittoja niin hyvin .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Galaxy S4
# sentence:  Ostin Htc Onelleni kuvan tyylisen flip coverin . Saako mitenkään , että kun suojan avaa , niin samalla näppäinlukko aukeaa , ja puhelin menee kotinäytölle ? Ja luonnollisesti kun suojan laittaa takaisin kiinni niin lukitus menee päälle ja näyttö pimenee ? Kaverillani on Galaxy S4 , ja siinä ainakin saa tällälailla . Olisi kätevä , kun tämän suojan kanssa lukitusnäppäimen painaminen tuntuu ainakin näin alkuun kovin luonnottomalta ( lukitus puhelimen yläosassa ) .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.3333333333333333], ['negative', 0.3333333333333333], ['mixed', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Holy Ghost !: in
# sentence:  Suomi-jazz kuuluu kyllä siihen tyyliin mihin en ole oikeastaan ollenkaan tutustunut . Vaikuttaa mielenkiintoiselta . Itsellä viimeisin poisto oli LCD Soundystemin - Drunk Girls sinkku , jonka B-puolella Holy Ghost !: in remixi . ( Aivan loistava remixi onkin ) 4.5/5
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Hugea
# sentence:  Hugea tuli ennen kuunneltua nykyään noi levyt on vaan tossa telineessä pölyttymässä . Sanotukset on ollut nykyyän vähän mitään sanovia ja tylsiä .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['negative', 0.3333333333333333], ['mixed', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Abigor
# sentence:  Abigor : ensisilmäyksellä pelkkää primitiivistä paahtoa , mutta jos sitä jaksaa kuunnella , paljastuu se erittäin monitasoiseksi pläkkikseksi :D
# predicted:  neutral , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Pink Floyd
# sentence:  Vanhana Pink Floyd fanina ei oikein toiminut . Toisaalta vika kappale , nervana iski siten että se oli kuunneltava ensi näkemältä kahdeksan kertaa putkeen . Muuten huono levy paitsi viiminen kappale .
# predicted:  ['negative'] , original sentiment labels:  [['positive', 0.3333333333333333], ['negative', 0.3333333333333333], ['mixed', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  MPC : n
# sentence:  Onkohan MPC : n softa oikeasti niin buginen ja huono kuin siitä puhutaan ? Saattaa nimittäin nyt videoiden perusteella Studiokin olla vaihtoehto ...
# predicted:  ['neutral'] , original sentiment labels:  [['negative', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Windows
# sentence:  Sulautetuissa varsinkin . Voisi olla joku sulautettu parempi lähestymistapa kuin Windows . Jos ei sulautettu kelpaa niin sitten Linux voisi olla seuraavaksi ja jos ei sekään niin sitten Windows .
# predicted:  neutral , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Qt : n
# sentence:  Jos perus c++ projekti , niin Qt ilman Qt : n kirjastoja ja jos jotain graafista niin Qt edelleen .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  bootstrapin
# sentence:  Bootstrapilla kyhäät melko nopeasti jonkun responsiivisen ja tyylikkään , mutta geneerisen sivun . Toki niitä bootstrapin oletustyylejä voi muokkailla sitten .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.25], ['neutral', 0.5], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  Barcan
# sentence:  Tossa kun huvikseni laskeskelin , niin päädyin sellaiseen lopputulokseen että Chelsean tällä kaudella pelanneet pelaajat maksoivat yhteensä 284 miljoonaa euroa ja Barcan 248 miljoonaa euroa . Eihän tossa ole eroa kuin yhden ylihinnoitellun pelaajan verran sisu liittyy :D
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Pelicanseja
# sentence:  Kummassakaan kirjoituksessa ei vaadita kenenkään alkaa kannattaa Pelicanseja vaikka kirjoitukset ovatkin julkaitu ko. seuran kannattajien sivuilla . Nuo ovat kannanottoja suomalaisen kannattajakulttuurin puolesta . Tue paikallistasi , tunnusta väriä , näytä tunnetta ja seiso omiesi takana loppuun asti ylpeänä hyvinä ja huonoina hetkinä . Luetun ymmärtäminen on tärkeä taito .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Ylen
# sentence:  Jotain aikatauluja olisi hyvä saada . Löytynee Ylen sivuilta ? Keihäänheitto eniten kiinnostaa nyt kun Pitkämäkikin on taas ollut vakuuttavassa vedossa .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.25], ['neutral', 0.5], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  Kotipizzan
# sentence:  Let ' s be honest here . Kotipizzan pizzat ovat hyviä , mutta ne ovat auttamattoman pieniä . Ja kalliita varsinkin kokoonsa nähden .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Fortumissa
# sentence:  Olisiko verouudistuksista kiinni ? Sijoittajat ei oikein tiedä miten uudet päästöverot vaikuttaa Fortumin tulokseen . Itse tankkaisin , mutta on jo ylipainoa Fortumissa .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['mixed', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  rautaruukkia
# sentence:  Melkoinen ostokiima ollut rautaruukkia kohtaan viimeiset viikot . Ilmeisesti yleinen usko terästeollisuuden nousuun syksyllä on nyt todella kova . Fumia pitäisi ostella osalla nokiasta tulleista rahoista .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  e36
# sentence:  Jo jonkin aikaa on tehny miel ostaa hyväkuntoinen ja vähän ajettu e36 mutta kai se on jotain muute harkittava kun kyseinen automalli on niin jonnea .
# predicted:  neutral , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  golfista
# sentence:  Juuh , en sitä tehojen takia osta , kuullut paljon hyvää golfista .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.25], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  s60
# sentence:  Broidilla oli s60 vm . - 04 , Meni 2000 € alustan korjaamiseen laatuosilla puolessa vuodessa . Tämän jälkeen alkoi hajoamaan samat osat samassa järjestyksessä uudestaan , eikä mitään aiheuttajaa löytynyt , joten auto kiertoon . Latiru meni kanssa pari kertaa vuoden aikana vaihtoon . TT
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  BMX
# sentence:  Jees , pistetään nimen mukainen lanka pystyyn ! Kiinnostais kuulla et onko ns. worth aloittaa tuo street dirt-laji , elikkä käytännössä BMX mutta vähän erilaisella pyörällä ? Onko muita lajin harrastajia ? Olis pari kysymystä mielessä ! :-D
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  TT-pyörän
# sentence:  Juu oishan se aerokypärä ihan paikallaan mikäli omistaa sen TT-pyörän , mutta en kyllä perus maantiefillarin kanssa sellaista pisaraa vetäisi päähän . Oletko liikkeellä kengännauhabudjetilla vai mikä mättää noissa maantiekypärissä ?
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  BMX
# sentence:  Liian kallista , muuten kyllä natsaisi . BMX riittää minulle kuitenkin .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.4], ['neutral', 0.6]]
# ------------------------------------------------------
# Target word:  Aviarkin
# sentence:  Joo jämäkkä ja nihkeä paras . Itsellä oli aikoinaan soft puttereita mutta hajontaa oli jostain syystä liikaa puteissa . vaihdoin koviin , kolina häiritsi ja pito tuntu lipsuvan . Välimallilla siis mennään , tuo DD Classic blend seos on tosi jämäkkä ja nihkeä eikä painu läjään niinkuin softit kun antaa peukalolla painetta pidemmissä puteissa ( kiekon muoto kädessä ei muutu ) . Aviarkin passais mutta tosissaan en ole löytänyt muovia joka toimis joka kelissä .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.25], ['neutral', 0.25], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  ps3 : sella
# sentence:  eli siis tuolle NAT-ongelmalle ei voi mitään ellei erikseen ota yhteyttä saunalahteen ? itsellä toimi moitteettomasti saunalahden kanssa nettipelailu ps3 : sella partyissa , mutta sitten joku alkoi kusta ja NAT-tyyppi vaihtui NAT2 : sesta NAT3 : een eikä parin kaverin kanssa pelaaminen ole onnistunut sen jälkeen vaikka satunnaisiin matseihin pääsisi .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['mixed', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  FireStrike
# sentence:  3DMarkista on ilmainen versio , jossa myös FireStrike . Tosin silloin pitää aina ajaa kaikki kolme testiä ja niiden esittelyvideot . Kuvassa omat settini , en ole ylikelloittamisen jälkeen kokeillut paljonko tulee .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Roccat
# sentence:  Tuo on hyvä näppis ! Itsekin käytin sitä puolitoista vuotta , kunnes bongasin tarjouksesta Ducky Shine 3 : n . Tuo Roccat oli tukeva rakenteeltaan , ei natissut tai nitissyt , kumitassut olivat hyvät eivätkä ne luistaneet ja näppäimet olivat sopivan jäykät .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Shadow Mechanics
# sentence:  Kuuntelin yhden biisin ja tuli hieman mieleen Demigodin Shadow Mechanics aikainen matsku . Valitettavasti yksitoikkoisempana vain .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.2], ['neutral', 0.4], ['negative', 0.4]]
# ------------------------------------------------------
# Target word:  WinForms
# sentence:  Nyt pistän pääni pölkyllä : WinForms on ihan ok .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Linuxinkin
# sentence:  Unohdit serverit ja supertietokoneet , mutta noin peruskäyttäjällä aika nappiin osuit . Jos sen jonkin Linuxin distroista saa vakaaksi ja kaikki ajurit toimintaan , niin kyllä se perusnettikoneena toimii oikein hyvin , kun ei ole Windowsin ongelmat häiritsemässä . Toki ne samat idiootit jotka saavat Windowsin solmuun , saavat aivan varmasti Linuxinkin .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  JS:stä
# sentence:  Pyhonin ja Rubyn suorituskyky on ihan onnetonta . V8 lienee ainut varteenotettava JS engine ja se suoriutuu ainakin micro benchmarkeissa kaikista skriptikielistä parhaiten . Tarkemmin ajatellen JS kyllä ominaisuuksiensa puolesta saattaisi sopia esim. desktoppiympäristön appleteiksi jos tulkin muistinkäyttö on hillittyä . Kielenä JS:stä en henk. koht. pidä .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.25], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  Officen
# sentence:  Methlab on maksullinen ja octaven toiminta on vähän niin ja näin kehitysprojektin epäsäännöllisen toiminnan takia . R on varmaan kaikista varmin ja halvin ratkaisu ja itse ainakin olen tykästynyt kovin . Mitään tekemistähän näillä ei ole Officen kanssa ja käyttäminen saattaa olla alkuun työlästä kun pitää kieltä opetella .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Raspberry
# sentence:  No taitaa tuo raspberry esimerkiksi viedä vähän enemmän virtaa . Atmega pyörii idlenä 1mA:lla , Raspberry varmaan 1A:lla . AP taas jonne joka ei tiedä asioista mitään .
# predicted:  ['negative'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Arsulla
# sentence:  Koitetaas ainakin ensimmäinen puoliaika pysyä hereillä . Arsulla onneksi Sagna & Gibbs jälleen ehjinä .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.25], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  FB
# sentence:  Täällä toinen nyymi jolla ei ole FB tunnuksia . Mitä niillä tekee ?
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  JYP:stä
# sentence:  SaiPa - JYP:stä luvassa aika tiukkaa vääntöä . Kisapuisto on ainakin ääriään myöten täynnä , se on selvä .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Perussuomalaisissa
# sentence:  Huomenna varmaan sanoo että häntä on tulkittu väärin kun saa soiton Soinilta . Myöhemmin Soini sitten kertoo taas kameroille miten Perussuomalaisissa kaikki saa ajatella niin kuin haluavat eikä puheita tai ääniä säädellä kuten vanhoissa puolueissa . Itse aiheesta sen verran että olisi kiinnostava nähdä asiasta dataa , mutta varovainen ei tuo välttämättä huono ajatus ole tälle ehdotukselle kun ottaa huomioon vaikkapa Hollannin ja Portugalin tilanteet .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Vasemmistoliittohan
# sentence:  Vasemmistoliittohan on lanseeraanut uuden termin alibudjetonti . Eli jos menoja leikataan ja vuositulos on silti alijäämäinen eli tarvitaan velkarahaa , on kysymyksessä vielä alibudjetointi . Ratkaisuna kai olisi aivan mahdottomat veronkorotukset ja pöhöttyminen , koska leikkauksia ei saisi tehdä mistään puolelta . Se , että jaetaan ainoastaan mitä on mahdollista jakaa on uusliberalismia .
# predicted:  ['negative'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Ebaysta
# sentence:  Menee nyt vähän aiheesta ohi , mutten viitsi kokonaan uutta lankaa tehdä . Eli mistä kannattaisi etsiskellä erinäistä viina merchandisea . Siis esim. viinamerkeillä brändättyjä shottilaseja , lasinalusia , shakereitä , jääastioita jne. Mitä nyt yleensä baareissakin näkee . Myydäänkö näitä missään vai tuputtavatko viinan valmistajat vain niitä tuotteidensa mukana baareihin ? Ebaysta nyt on olen jonkun verran katsellut , mutta valikoimat ovat satunnaisia ja pieniä , sekä toimituskulut naurettavia . Kiitos vinkeistä jo etukäteen .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['negative', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  A6 C6
# sentence:  Osta A6 C6 . Tässä vissiin tilanne on toisinpäin , eli saat huollattaa moottoria , mutta laitteet ei temppuile .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.4], ['mixed', 0.6]]
# ------------------------------------------------------
# Target word:  Oakleyn
# sentence:  Itse käytän Oakleyn laseja , kalliita tosin verrattuna moniin muihin . Kerralla kun ostaa hyvät niin ei tarvii toiste ostaa , linssejä voi vaihtaa lennosta myös .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  telen
# sentence:  Lisätään vielä että liikenteen prioriteetti on varmasti suurempi soneran kuin telen liittymissä .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  a-jays kolmoset
# sentence:  itse ostin a-jays kolmoset . hieman pettynyt basson uupumiseen ja liian kirkkaaseen saundiin . ihan hyvät peruskuulokkeet noin muuten . ovat kyllä pakattu hienosti ja mukana tulee kantokotelo yms. krääsää .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Windowsin
# sentence:  Tuttu ongelma . Windows vetänyt itsensä solmuun eikä osaa käynnistää e xp lorer . exeä bootissa . Uusi tehtävä - e xp lorer . exe Käytä tota kikkaa siihen asti kunnes jaksat asentaa Windowsin uusiksi tai vika selviää muuten . En oo koskaan jaksanu vikaa rueta sen koommin ettii koska uudelleenasennus on niin nopea toimenpide .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Lumia 920 : ssa
# sentence:  Reilu viikko sitten oli samaa ongelmaa Lumia 920 : ssa . Liekkö joku operaattorin onkelma .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  yamahan
# sentence:  Haluan kirkkaan soundin , joka tulee sijaitsemaan suht kaukana virtuaalisessa tilassa . Kitara on tällainen yamahan perus , vähän päälle satasen halpisnylonkielinen . Onko mitään suositusta minkä tyyppistä mikin sijoitusta kannattaa kokeilla ensimmäiseksi ?
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Java 5
# sentence:  Ei se ihan niinkään ole . Java 7 on nyt se juttu ja siinä on aika monta uutta vipua ( switch muun muassa ) . Java 5 tiedoilla ei pärjää eikä varsinkaan alle Java 5.
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Barcan
# sentence:  Varmaan osasyy Barcan hampaattomuuteen oli Vilanovan sivussaolo . Ei tullut riittäviä lääkkeitä taktisesti kun niitä olisi tarvittu .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Kokoomusta
# sentence:  Mites noi demarit ? Ja työväki äänestää lähestulkoon mitä tahansa puoluetta , jopa Kokoomusta
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  vihreiden
# sentence:  Jos perussuomalaisten varavaltuutetut ovat ongelma , niin ovat myös yksittäiset vihreiden valtuutetut .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.25], ['negative', 0.5], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  Greenpeacea
# sentence:  Niin , uskon kyllä että Greenpeacea ( tai mitä tahansa muuta ryhmää ) sokeasti fanittaville tyypeille se on vaikeaa .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Persujen
# sentence:  ... ja jos vanhat merkit pitävät paikkaansa niin Persujen kannatus vaalipäivänä on gallup-lukemista huolimatta vain noin 12% . Viime euro- ja kuntavaaleissa PS:lle taidettiin ennustaa n. 16-17% lukemia , mutta ei se ihan niin mennytkään .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Facebookissa
# sentence:  Kaveri diilaa nuuskaa . Pari kertaa vuodessa hakee jollain 3000-5000€ nuuskaa ruotsista ja myy töissä ainakin ihan avoimesti . Facebookissa on seinällä ilmoitusta että on nuuskaa tarjoilla . Kuukaudessa menee yleensä kaikki ja sillä kuulemma tuplaa alkusijoituksensa kevyesti . Helppoa rahaa .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Ebaysta
# sentence:  Paypal ei tule eroamaan Ebaysta vielä pitkään aikaan jos koskaan .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  SMC : thän
# sentence:  SMC : thän on LC4 koneisia , aikamoisia matkalehmiä siis .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.25], ['neutral', 0.25], ['negative', 0.25], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  Opeleita
# sentence:  Okei ruma , mutta olisi varmaan menekkiä ollut . Saab oli / on aika outo pulju . 80 - ja 90 - luvuilla ei ollut diesel - , farmari - tai nelivetomalleja ollenkaan . Kaiken kruunasi että ysärin lopussa Saabeista alettiin tekemään Opeleita .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.25], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  A5 - audin
# sentence:  Mersu tietenkin . Onhan se huomattavasti arvokkaampi auto . Kummallakaan en tekisi yhtään mitään ja tuonkaltaiset autot ei kiinnosta , joten myisin auton välittömästi ja ostaisin jonkun mielekkäämmän valinnan . Tavallinen S - sarjan coupen tai A5 - audin voisin jopa pitääkin , nuo RS - AMG - yms mallit ei herätä juurikaan omistamisen haluja . Ei sen puoleen että nuo olisi keskenään kovin vertailukelpoinen pari , edustavat hieman eri autoluokkia
# predicted:  ['negative'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['negative', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  thinkpadit
# sentence:  Mikä HP ? Itsellä tollanen omnibook xe4500 kanssa 1400x1050 näytöllä ahkerassa käytössä ja vehje jo varmaan 10 vuotias . Löytyy myös Thinkpadeja parikin , T40 joka kylläkin bugailee kaikennäköistä muistiensa kanssa ja T42 joka kyllä pelaa kuin junan vessa mutta Ati FireGL korventaa reidet verille jos sylissä käyttelee Win7 kanssa . Muuten toki loistavia vehkeitä kaikki IBM-aikaiset thinkpadit lähes poikkeuksetta sekä tiettyyn rajaan asti Lenovo-merkillä olevat T- ja X-series .
# predicted:  ['neutral'] , original sentiment labels:  [['mixed', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Cyanegenmodia
# sentence:  Se on ihan erin näköinen kuin HTC : n Sense käyttöliittymä . Ja puhelimesta ei löydy kuin esiasennetut appsit ja asetukset on nollatu . Eli et ole asentanut sitä Cyanegenmodia .
# predicted:  ['negative'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.25], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  MS Sidewinder X6
# sentence:  Itselläni oli ennen MS Sidewinder X6 , josta sai numpädin pois , ja se sopi täydellisesti 15 , 4 läppärini oman näppiksen päälle . Tuollaista mattoa en itse ainakaan haluaisi , kirjoutustuntuma on erittäin huono .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Coffeescriptissä
# sentence:  Mutta onko Coffeescriptissä mitään sellaista niin järisyttävää uutta jota JS ei tarjoaisi . Kuulostaa hieman hipsteriprojektilta jonka käytännön hyödyt jäävät vähäisiksi . Matalaa tason koodia tuskin kukaan haluaa pyörittää selaimissa missään muussa muodossa kuin plugareissa . Kyllä se pitää olla virtuaalikone ja tulkki missä homma skulaa .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.25], ['negative', 0.5], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  Microsoftin
# sentence:  Us-ko-ma-ton-ta , miten tämä ei ole tullut itselleni mieleen ? Olen itse käyttänyt LibreOfficea jo pitkään , mutta Word on opiskelupiireissä huomattavasti suositumpi eikä LO pidä Microsoftin formaateista . Tallentamalla ODF-muotoon homma toimii molempiin suuntiin ja oman osuuden teko ryhmätöistä helpottui huomattavasti . Kiitoksia tästä ! T . Ilmeisesti hitaasti käyvä teekkari
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Windows
# sentence:  Miksi python tai php eivät sitten ole oikeita ohjelmointikieliä ? Kieli riippuu siitä mitä haluat tehdä . Jos haluat tehdä ajurin linux kerneliin tai muita matalan tason juttuja niin C. Jos haluat ohjelmoida softaa androidille niin Java . Jos haluat koodata Windows ohjelmistoa niin vaikkapa C# jne. ..
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Youtubessa
# sentence:  Sitten kun saat oman ohjelmasi toimimaan , olet testannut sitä sekä muut on käyttänyt ja mahdollisesti viimeistelty asennuksella + ikoneilla . Ts . teet JEE softan joka pyörii jossain ja sitä oikeasti voi käyttää ja se tekee tarkoitettua asiaa . Android ohjelma joka toimii moitteetta ja on mahdollisesti ladattavissa GooglePlaystä tai sen toiminnasta on video Youtubessa . PC desktoppi ohjelma joka edellisten mukaan tekee luvatun asian kaatuilematta eikä ole resurssi hogi .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Leijonat
# sentence:  Hyvä suami kalia ja viuna :DDDDDDD 2-1 on paras ja Noge .. Mitä helvettiä Leijonat .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.2], ['mixed', 0.2], ['unclear', 0.6]]
# ------------------------------------------------------
# Target word:  ManU:lla
# sentence:  Glorifioitu ystävyysottelu jossa ei ole ManU:lla mitään pelissä , toivottavasti mahdollisimman monta junnua yms. B-tiimiläistä pääsee kokeilemaan siipiään .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['negative', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Euraasian unioniin
# sentence:  Kazakstanin pitäisi tulla mukaan Euraasian unioniin muutenkin . Jos Nazarbajev pelaa korttinsa hyvin ( ja on tosi kiltisti Kremlin suuntaan ) , niin en usko , että mitään uutta sotaa tulee sille suunnalle . Mutta jos Kazakstan haluaa leikkiä oikeasti itsenäistä valtiota samaan aikaan kun yhdentyy ja liittoutuu yhä tiiviimmin Venäjän kanssa , niin se ei välttämättä toimi ...
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Bombay Sapphire Eastiä
# sentence:  Viestin rohkaisemana ajattelin itsekin kysyä arvon baarimestarilta , että minkälaisia drinkkejä olisi mahdollista valmistaa , kun kaapista löytyisi Johnny Walkerin Red labelia , vaalea rommia ( Bacardi ) , Bombay Sapphire Eastiä ja ikivanhaa Martinin punaista vermuttia ? Rommista olen Cuba Libre - virityksiä duunannut , mutta mitäs muuta olisi tarjolla ?
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Nokian renkaat
# sentence:  Kahden eri firman osakkeeseen itse sijottaisin . Itsekin aloitin osakesijoittamiseni aikanaan 1200e kun laitoin 600e+600e kahteen yritykseen . En tiedä kuinka kärsimätön olet tuoton kanssa mutta jos maltat odottaa useamman vuoden niin ostaisin nyt venäjän kriisien takia arvonsa laskeneita firmoja , esim Nokian renkaat . Täysin tyhjin käsin et jäisi ensimmäiseltäkään vuodelta sillä Nokian renkaat on ollut suht hyvä osingonmaksaja . Mutta mistäpä näitä osaa sanoa ..
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Elisa
# sentence:  Juuh kyllä Elisa näistä Suomen telefirmoista on paras . TeliaSoneralla on omat ongelmansa ja DNA alkaa olla pystyyn kuollut . Parin vuoden sisällä kaikki operaattorit tulevat ottamaan käyttöön mobiilidatakaton TeliaSoneran vanavedessä . Liiketoimintamalli , missä datan käyttö moninkertaistuu vuosittain , mutta hinnat polkevat paikallaan ei ole kestävä . Elisa on tosin turhan kallis tällä hetkellä , mutta jos vakautta hakee niin ihan ok kohde parkkeerata pääomat .
# predicted:  ['positive'] , original sentiment labels:  [['negative', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Arlallakin
# sentence:  Onkos tässä tapauksessa se 2 , 5€ paljon vai vähän . Jos se on mielestäsi paljon ja ylihinnoiteltu niin eikös Arlallakin ole jugurtteja kaupan hyllyt täynnä ... Siitä vaan tarjoamaan halvempaa ei-laktoositonta tuotetta jos pystyvät . Siinähän on oiva markkinarako jollekin .
# predicted:  ['neutral'] , original sentiment labels:  [['mixed', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Volvon
# sentence:  Volvon päämuotoilijan , Jan Wilsgaardin tiedetään sanoneen tiiliskivistään : " Ajaton koti ei ole hyvän näköinen ensisilmäyksellä " .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Nissan Sunny
# sentence:  Oma ensiautoni oli 250 € maksanut vuosimallin 1982 Nissan Sunny . Aivan kaamea härveli näin yleisesti , mutta olihan siinä tiettyä fiilistä , jota ei uudemmista autoista löydy . Paaliin sekin meni sitten , kun vähän jokainen paikka hajosi , eikä mokomaa enää kannattanut korjailla .
# predicted:  ['negative'] , original sentiment labels:  [['negative', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Asuksen
# sentence:  Itselläni teki Asuksen mallin kanssa samaa , takuuta vastaan vaihtoivat uuteen , eikä ääntä enää esiintynyt .
# predicted:  ['neutral'] , original sentiment labels:  [['negative', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  PayPal
# sentence:  PayPal näyttäisi olevan maksuvaihtoehtona , joten eiköhän se ihan legitti kauppa ole . Rahat saa ainakin sen kautta helposti takaisin .
# predicted:  ['negative'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  razerit
# sentence:  RaZeR on ainut oikea Peli_miähen hiiri tää Zowie kyllä vie toimivuudella , yksinkertaisuudella ja mukavuudella kaikki razerit , vaikka ei omaakkaan makronappeja ja ledejä
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.3333333333333333], ['negative', 0.3333333333333333], ['mixed', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Microsoftin
# sentence:  älä nyt vaan ala väittämään että jollain libre officella tekisi jotain kun yhteensopivuus Microsoftin tuotteiden kanssa on ihan naurettavalla tasolla .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.6], ['negative', 0.2], ['unclear', 0.2]]
# ------------------------------------------------------
# Target word:  ubuntua
# sentence:  Naurattaa kyllä tää jengin viha ubuntua kohtaan . Porukalla sama reaktio kun uskovaiselta jolta kysytään saako kertoa luciferista .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Presidenttiä
# sentence:  Oltiin noista mielenosoittajista mitä mieltä tahansa , et kai edes sinä voi olla niin yksinkertain , että tuolla kiisteltäisiin vain siitä , että juodaanko tuolla juhlissa Presidenttiä vai Rainbow-kahvia , eli kyse olisi juhlien hinnasta eikä suuremmista yhteiskunnallisista asioista ja ongelmista ?
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['negative', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Liptonin
# sentence:  Tällä hetkellä Liptonin vihreä sitrushedelmätee . Tässä on mukana kuivattuja hedelmänpaloja eikä siis esansseja . Pitää katsoa jos löytyisi jotain muutakin irtoteetä kaupasta , aiemmin käytin teepusseja . Huononeeko teen maku jos pussia ei sulje kunnolla vaan jättää auki ?
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.25], ['neutral', 0.5], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  G3220
# sentence:  G3220 maksaa noin 50€ ja lähed jokainen peli pyörii sillä , paitsi arma III sulavasti
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.25], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  GCC
# sentence:  Pelkkä editori , GCC ja makefilet on hyvä kombo pieniin projekteihin . IDEstä voi olla iloa jos on iso projekti ja kehitysympäristö tarjoaa hyviä työkaluja kompleksisuudenhallintaan mutta ei se silloinkaan välttämätön ole .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Mintin
# sentence:  Tulin vain kiittämään hyvästä ja asiallisesta langasta . Lurkkaillessa tämä on ollut ensimmäinen mistä löytynyt viesteille jotain katetta eikä pelkkää paskanjauhantaa . Taidanpa itekkin alotella laittamalla jonkun distron ( näillänäkymin Mintin ) vanhemmalle läppärille . En usko että kovin korkeita speccejä ainakaan pienten ohjelmien kanssa tarvisi ..?
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Glenlivet 12
# sentence:  No jestas . EI täällä ihan noin kalliita hintoja ainakaan ole ollut . Ardbeg 10 yo maksoi eräässä paikassa kympin ja Glenlivet 12 toisessa paikassa 7€ . Ne on mielestäni ihan sopivia hintoja tesmailuun .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Elisan
# sentence:  Elisa ja Kesko on tunnettu perinteisesti hyvinä osingonmaksajina . Tosin Elisa on jakanut osinkoa aika löysällä kädellä ja firma onkin aika velkainen . Keskolla taas bisnekset eivät oikein luista , mutta kova kulukuuri on pitänyt voitot kohtuullisina ja osingoista on myös pidetty huoli . Eivät todellakaan ole mitään pikavoittoja . Tasaisempia firmoja saa hakea . Telebisnes ehkä vähän riskisempää , mutta Elisan asema Suomessa ei horju .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  IB : n
# sentence:  IB : n kanssa toimiessa täytyy ilmeisesti toimittaa kaikki tiedot voitoista/tappioista verottajalle itse ?
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  940
# sentence:  Tarkoitus olisi ostaa b230ft koneellinen volvo , kun nuo on muutenkin niin halpoja . Mutta ostaakko 740 vai 940 ? 740 olisi ainakin kevyempi ja mahdollisesti halvempi ( harvoin myynnissä , nyt yksi ) , mutta 940 olisi varmaan turbomallissa jo vähän varusteita ja lukkoperä yleisempi . Mites muut jutut mitä en ota huomioon , kone on ilmeisesti päivitetty tuossa 960 mallissa ? Ainakin kovempia vääntölukemia löysin kun etsin tietoa .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.25], ['neutral', 0.25], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  bemarit
# sentence:  Koska itsellä ainakin se kaikkein juntein kaveri ajaa bemarilla . Kaikki muut merkit on paskaa , poliisit on homoja ja nopeusrajoitukset on niille jotka ei osaa ajaa . On parilla muullakin kaverilla bemarit ja ovat ihan normaaleja tyyppejä mutta tämä yksi leimaa sen joukon .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.25], ['negative', 0.25], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  E30 : stä
# sentence:  Onkohan tuosta kuvan E30 : stä korjattu taka - akselin geometria ? Vakio kun on suunniteltu päin persettä .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Audin
# sentence:  Kyllä se totuus on että Audin V8 : t ovat aikalailla elinkaarensa päässä 300tkm . Toki niitä voi elvytellä vaihtamalla isolla rahalla osia parin kuukauden välein , mutta missä järki ? Siinä että saat vähän isompi ruokaisen auton ? V8 moottorit ovat niitä varten kellä on varaa ajaa se sielt Audilta uutena ulos . Loppu elinkaari niillä autoilla on kädestä suuhun elävillä rikkailla
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Turun jujutsuseuraa
# sentence:  Ei vissiin mitään kunnollista ainakaan . Kannattaa suosiolla lähteä keskustan ulkopuolelle . Suosittelen joko Finnfighters gymiä tai Turun jujutsuseuraa . Finnfighters enemmän lukkopaini/vapari . TJJS BJJ puvulla ja ilman , lisäksi kickboxing . Ei varsinaista vaparia .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Maurice Mongoose
# sentence:  Tsekkaa ennemmin vaikka Charge Plug , Fuji Feather , jopa Maurice Mongoose ( löytyy Citymarketista ) jne
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Salomonin SC 1
# sentence:  Kokemusta lasikuitusauvoista ? Salomonin SC 1 sauvat kiikarissa , olisi kiva jotain kommentteja kuulla jos kellään kokemusta vastaavista .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Thinkpad T60
# sentence:  Tuu hakemaan multa Thinkpad T60 jos asut Helsingissä tai lähellä . Löytyy coreboot tuki ja käsittääkseni myös hyvä OpenBSD - tuki . Lisäksi prossusta puuttuu vpro - vakoiluominaisuus .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  GTX 970
# sentence:  Jos on pari kappaletta GTX 970 tai 980 näyttiksiä , onnistuu myös 4K-resolla pelien ja ohjelmien ajaminen .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  w7
# sentence:  Kannatteko läppärin joka päivä koululle ? Oma w7 läppäri painaa sellaiset 3 kiloa .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  fifalta
# sentence:  Juu , en huomannut tätä keskustelua . Mutta niin , Suarez ei mukana joka oli ylivoimaisesti paras kärki viime kaudella , Tekopyhää fifalta kun kuitenkin niinkin hullu henkilö kuin Diego Costa on mukana . Muutenkin usko FIFA:an on aika lailla hiipunut olemattomiin . Eiköhän se ole tämä hyväveli-verkosto joka tätäkin lajia pyörittää .
# predicted:  ['negative'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  SaiPassa
# sentence:  Motivaationpuute on kyllä näkyvissä , mutta tiedä sitten onko se sitä ettei pelaakaan NHL:ssä . Kyllähän ammattilainen tuossa iässä on sen jo enemmän tai vähemmän hyväksynyt joten ei pitäisi noin pahasti näkyä pelissä . Kenties ankeat Oulun olot , joukkuekaverit , valmennus tai muut syyt aiheuttaa sen että kaikkea ei saa irti , kuitenkin SaiPassa oli korvaamaton ukkeli
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Atrian
# sentence:  Asun itse kaupungissa , mutta fakta taitaa olla että tuolla maalla syödään huomattavasti laadukkaampaa ruokaa aidosti tuoreista ja paikallisista raaka-aineista . Kaupungeissa sit esim työpaikoilla syödään lounaalla Atrian pizzoja ja lihapiirakoita . Joukkoon mahtuu ehkä pari herrasmieslarppaajaa , jotka käyvät kalliilla syömässä sitä samaa junttien tuottamaa lähiruokaa .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.4], ['negative', 0.6]]
# ------------------------------------------------------
# Target word:  A3 : sta
# sentence:  Haluaisin vain hauska takavedollisen hatchbackin . Audi A3 Quattrolla olisi ollut kiva , mikäli kyse olisi ollut oikeasti quattrosta . Haldex ratkaisun takia en oikein A3 : sta myöskään halua , vaan se olisi sitten A4 quattrolla vähintään .
# predicted:  neutral , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Toyotat
# sentence:  Toyotat löytyvät aina huoltotilastojen parhaimmilta paikoilta . Suuri autokanta Suomessa tarkoittaa myös helposti saatavia varaosia .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.25], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  Sambo
# sentence:  Siis eihän siinä mitään ongelmaa olekkaan . Tosin tuntuu , että nykyään kaikki harrastavat vapaaottelua , niin olisinko tuu mainstream , jos itsekkin sinne menisin . Sambo on osittain kiinnostanut , mutta kotikaupungista ei taida löytyä opettajia sille .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  windows 98
# sentence:  Jos teet windows 98 virtuaalikoneen niin voit pelata hyvin vanhoja pelejä .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  android
# sentence:  Voitteko antaa jotkut ohjeet for dummies , miten android kännykästä saa mahdollisimman paljon yksityisyyttäni kunnioittavan . Eli pois kaikki paikkallistamispalvelujen eteenpäin välitykset ja muut .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.25], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  xo nar DG
# sentence:  äänikorttina xo nar DG jota on tullut käytettyä myös kohta vuosi . ikinä ei ennen ongelmia .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Nexus 5 : n
# sentence:  Musiikin säilytykseen . Vanhassa SGS3 : ssa oli muistikortilla pelkästään musiikkia ja Cyanogenmodin varmuuskopiot kaatumisen varalta . Nexus 5 : n kanssa saa käyttää muistia vähän konservatiivisemmin , kun ei huvita maksaa 50€ ylimääräistä 16gb lisämuistista . Erillinen DAP tulee ensi vuonna , joten ei tuolla sinänsä niin väliä .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.25], ['negative', 0.5], ['mixed', 0.25]]
# ------------------------------------------------------
# Target word:  Win98
# sentence:  Jostain syystä jotkut Win95 pelit ei vaan toiminut Win98 : ssa . Muutamaan peliin tuli sitten Win98 fix päivityksiä ... mm. tuohon Star Trek Borgiin .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Kontakt player
# sentence:  Kontakt player on ilmainen ja toimii melkein samalla tavalla .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Facebookin
# sentence:  Tämä . Jollain Facebookin UI-suunnittelijalla olikin hyvä pointti aiheesta : mitä vähemmän itse softa on esillä , sitä parempi . Pyritään siis minimoimaan jonkun tietyn tehtävän suorittamiseen vaadittava aika ja aivotyö .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  NVIDIAllakin
# sentence:  NVIDIA suosittelee CUDA:a , poliittisista syistä . CUDAsta tuli juuri uusi versiokin 6.5. Iso paketti se , mutta toimii ihan heittämällä . OpenCL-tuki on NVIDIAllakin jäljessä tehoiltaan ja CUDA se optimi . Muilla valmistajilla pahasti kirittävää OpenCL:ssä . GPGPU-juttuihin voi suositella lähinnä Mantlea ja CUDAa .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['mixed', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Chelsealle
# sentence:  Kestipäs yllättävän kauan , että tällainen lanka tupsahti . Onnittelut Chelsealle .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  Grandiosan Classicia
# sentence:  En saa enää alas ilman älytöntä ähkyä edes Grandiosan Classicia . Tollasella eläis pari päivää hyvin .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['negative', 0.3333333333333333], ['mixed', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Lidlin sharp cheddaria
# ...
# predicted:  positive , original sentiment labels:  ['unclear']
# ------------------------------------------------------
# Target word:  Corollassa
# sentence:  Harmi että tuossa Corollassa on niin hirveä sisusta . Muuten vaikuttaa sopivan omalaatuiselta kulkupeliltä .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Specialfinin
# sentence:  Omassa seurassamme kurssi maksaa 400e , sisältäen materiaalit ja maksut liitolle . Kuuluu myös kamavuokrat kurssin ajaksi . Ja noita volo raceja itse käytin joskus , eipä mitenkään kummoiset . Nyt tosin pyrin käyttämään Specialfinin lasikuituräpylöitä jotka on tehty vähän eri hommiin . Ja kaikki snorkkelit joissa on joku poistoventtiili tai haitariputkea on paskaa , ja tämä on fakta . Eivät koskaan tyhjene yhtä hyvin kuin yhdestä putkesta veistetty vastineensa .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['negative', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  wintoosan
# sentence:  Minulla oli ihan samaa , kestin sitä jonkun 4kk ja sitten päätin asentaa wintoosan uusiksi ja nyt on toiminut ihan normaalisti , paria usbport . sys kaatumisia lukuun ottamatta .
# predicted:  ['neutral'] , original sentiment labels:  [['mixed', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  FreePascal
# sentence:  Haha , ei saatana . Taidan tietää , missä koulussa olet . Joskus noista oli tehty kyselyä eli millä yläasteilla on käytössä ATK:ssa ohjelmointia Turbo Pascalilla ja yli 20-30 vuotta vanha OPPILASMONISTE , josta noita oppeja luetaan . Teidän opettajat on ihan ammattitaidottomia sontasäkkejä . Pascaliin saa modernit GUI-pohjaiset softat nykyään kaikille alustoille . Mainitaan nyt FreePascal , jos ei opetuskäyttöön olevia lasketa .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['negative', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  940
# sentence:  paljos toi 740 2 , 3 kaasari vie pensaa lintta käytös ja kaupinki pyöritykses entä 940 ?
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  samsung
# sentence:  Onnea vain , jos lumia tuntuu omalta niin osta pois vaan . Kyllä huonomman luokan androidikin menee , mutta yleensä ovat pilattu bloatwarella ( Lue : edelleen samsung ) Joka pistää puhelimen tukkoon ajan kanssa .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  740i : ssä
# sentence:  740i : ssä ei ole turboja joten niiden vaihtaminen ei korjannut ongelmaasi .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  SFC 550w
# sentence:  Olisiko suositella mitään PSU merkkiä ? Jos sattuisin saamaan samaan hintaan toiselta valmistajalta PSUn takuuta vastaan ( mahdollisesti lahjakortti ) . Fractal ja Corsair tuntuvat jotenkin heikoilta . En tiedä miten tuo AMD liittyy virtalähteen vinkumiseen , mutta vanhalla 6870 kuuluu samalla tavalla vinkuminen kuin uudella r9 280x:llä corsairin kanssa , muttei vanhan SFC 550w kanssa . ( Mistä tiesit että omaan AMD : n kortin ? :D)
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  chelsealla
# sentence:  kuinkas monta manageria chelsealla on ollut 10 viime vuoden aikana :D
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Oakland Athletics
# sentence:  bump ! Oaklandissa meneillään jo 14.vuoropari ! Äsken pesät täynnä Yankeesin lyontivuorolla , mutta 2paloa alla ja Texeira lyö helpon pallon Oaklandin pelaajalle napattavaksi ja peli säilyy numeroissa 2-2. Peli siis NY Yankees - Oakland Athletics .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Tappara
# sentence:  Tänään HIFK ja Tappara . Ja rahan tuloa ei voi estää
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['mixed', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Aamulehti
# sentence:  Turun sanomatko Kokoomusvetoinen ? Olen sitä viimeisen kolmen vuoden aikana lueskellut , enkä ole ainakaan sen suuremmin sen olevan oikealla , ainakaan läheskään yhtä vahvasti kuin vaikkapa Aamulehti . Kenties piilottavat sen paremmin ja olen tietämättäni syönyt herrojen propagandaa perkele .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Googlesta
# sentence:  Siis nyt on niin yksinkertainen juoma kyseessä , että eikun reseptiä Googlesta ja itse tekemään ja maistamaan .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Fiat puntolla
# sentence:  Eli . Ajan Fiat puntolla , varusteita siinä on tuulilasin lisäksi ei mitään . Siinä se on se tankki sielä oikealla puolella .
# predicted:  ['negative'] , original sentiment labels:  [['mixed', 0.5], ['unclear', 0.5]]
# ------------------------------------------------------
# Target word:  S Mersua
# sentence:  Ökybemaristilla on E38 . Luksusaudistilla on A8 . Herra öky kävi katsomassa S Mersua .
# predicted:  positive , original sentiment labels:  ['unclear']
# ------------------------------------------------------
# Target word:  Super 7
# sentence:  Totta . Tingittävä on jostain . Tässä tapauksessa suorituskyvystä huolletuilla , eikä se minulle ole mikään ongelma . Olisi myös kiva kuulla muista saman typpisistä suksista mm. Rossignol Soul ja Super 7. Linen sir francis baconikin on osunut positiivisesti silmään .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  PS4 : llä
# sentence:  Täytynee vielä myös odottaa GTA V : n julkaisua ja miten osaa hyödyntää niitä kuutta ydintä . Luulisi kyllä että niiden on pakko optimoida ottamaan kaikki mahdollinen irti niistä kuudesta ytimestä PS4 : llä joten se osaa hyödyntää .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.3333333333333333], ['mixed', 0.3333333333333333], ['unclear', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Pythonin
# sentence:  Kiinnostaako nettisivut ? Jos kiinnostaa , niin Python on myös siten hyvä , että kun olet opetellut perusasiat , voit pikku hiljaa siirtyä Pythonin web-frameworkkeihin kuten Djangoon ja Flaskiin .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  mtv sportilla
# sentence:  Maikkarilla oli oikeudet ja esittikin Serie A : ta mtv sportilla vielä muutama vuosi sitten . Ilmeisesti katsojaluvut liian alhaisia , eikä esittäminen kannattanut
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  Sparebanken Vest
# sentence:  Lähti Awilcoa 100 kappaletta ostoon . Toinen uusi Norjalainen tulokas viikon takaa on Sparebanken Vest .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Legnum V4
# sentence:  Niin ja jos Mitsubishilta haluaa sedania tai farkkua , niin on myös nuo Galant VR4 ja Legnum V4 mallit . Legnumin tapauksessa , jos automaattia hakee , suosittelen lämpimästi Type - S mallia . Eivät nuo mitään tykkejä ole , mutta kyllä nekin kulkevat . Kuva .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['mixed', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  Dynamic discs : n
# sentence:  Onko noida Dynamic discs : n kiekkoja jossain kaupassa vai saako niitä vain verkkokaupoista ? Paljon kehuttuja nuo putterit , mutta hypistelemättä en osta . Ei juurikaan aktiivisest kiekkoa heittiviä kavereita niin ei voi kenenkään omaa kokeilla .
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Qt Mobile
# sentence:  Mitä oikein kehität jos html + js on liian hidasta ? Miten olis Qt Mobile ?
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Civiccini
# sentence:  Olen nyt omistanut 318 - 94 ( kangaspenkit ) 2vuotta ja olen ollut autoon hyvin tyytyväinen . Tarjoaa enemmän mukavuutta ja suorituskykyä kuin aikaisempi Civiccini .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.3333333333333333], ['neutral', 0.3333333333333333], ['negative', 0.3333333333333333]]
# ------------------------------------------------------
# Target word:  linuxilla
# sentence:  Rikki joka paikasta ? Miksi ? Miten ? En toki sano ettei linuxilla ongelmia olisi .
# predicted:  neutral , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Katsomokin
# sentence:  Jaa . Aika erikoista touhua , että ei televisioida ja Katsomokin tuntuu bugaavan . Katsojia kyllä löytyisi .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  audi S3 : ssa
# sentence:  Uudessa R - kolffissa , joka siis vertailussakin oli , on 300hp . Sana kone kuin uudessa audi S3 : ssa , johon myös oli verrattu .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Corsa
# sentence:  Nyt on hakusessa noin 1500e auto mahdollisimman pienillä käyttökuluilla . Nopeasti ajateltuna joku Micran kokoluokan auto tulisi halvemmaksi kuin perus 1 . 6l sedan . Miten se on todellisuudessa ? Onko 1 . 6l japsi sedan kalliimpi pitää kuin esimerkiksi Micra , Corsa tai vastaava ?
# predicted:  ['neutral'] , original sentiment labels:  [['positive', 0.25], ['neutral', 0.5], ['unclear', 0.25]]
# ------------------------------------------------------
# Target word:  UCI : n
# sentence:  Lisätietoja : UCI : n lajimääritelmän mukaan maantiepyöräily = cycling on paved roads
# predicted:  positive , original sentiment labels:  ['unclear']
# ------------------------------------------------------
# Target word:  CM Elite 430
# sentence:  Kannattaako ikkunalliseen ja muutenkin ilmavaan koteloon laittaa äänenvaimennusmattoa ? Kotelo siis CM Elite 430
# predicted:  neutral , original sentiment labels:  ['unclear']
# ------------------------------------------------------
# Target word:  svartin
# sentence:  Svart tekee kyllä kulttuurityötä tuolla uusintajulkaisemisella Itsellä monia svartin uusintoja , tuo ääretön joulukin löytyy punaisella vinyylillä
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Shellin
# sentence:  Mitä tähän keissiin on tullut tutustuttua , niin onhan tuo tilintarkastus ihan paikallaan . Mutulla heittäisin , että kaikkine investointineenkin tuo jään murtaminen Shellin laskuun on voitollista , mutta kieltämättä riskit ovat aika vahvasti Suomen valtion puolella .
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  EU : n
# sentence:  Verotuksen uudelleenjärjestely niin että se tukee pienten yritysten kasvua suuriksi , julkisen sektorin pienentäminen byrokratiaa ja turhia kuntia karsimalla , maltillinen velanotto , EU : n politiikan kurssin suunnan muutoksen vaatiminen . Tämän jälkeen julkisen sektorin ylläpitäminen sen kokoisena mitä se on ja kasvattaa se vasta seuraavassa lamassa nykyisenkaltaisekseen jos niin pitkälle on mentävä .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  corolla
# sentence:  Höpötystä , ihan yhtälailla siitä kuluu osat kuin muistakin autoista . Ja juurihan näitä parempia autoja ostaa ne , jotka ajaa paljon , joten ei se corolla ole siinäkään parempi . Ainoastaan halvempi .
# predicted:  negative , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Moto G
# sentence:  Varmaan kaikilla toi vika vähänkin pidemmän käytön jälkeen . Mutta tuleeko nyymeiltä muita ehdotuksia tuohon 200-300 hintaluokkaan kuin tuo Moto G.
# predicted:  ['positive'] , original sentiment labels:  [['neutral', 0.5], ['mixed', 0.5]]
# ------------------------------------------------------
# Target word:  bmw
# sentence:  Nii , bmw painii ihan hyvin mutta kevyemmässä sarjassa ja ei mene kauaakaan kun bemareita puolusteleva kaveri huomaa videoiden loppuneen . Miksi pitää edes tapella näistä asioista ? Kummatkin on todella hyviä autoja ja nyt tapellaan vain toistemme mieltymyksistä .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  bemari
# sentence:  No mulla on aivot päässä . Kuivalla pitävällä alustalla bemari vie , muutoin ei ikinä .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------
# Target word:  Ebay
# sentence:  Siilistä en tiedä mitään . Mutta Ebay on ihan ok ostos . Paras noista kampanja firmoista .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Volvoon
# sentence:  Ne kepin puslat olisi hyvä vaihtaa edes 500tkm välein vähintään , mielellään useammin niin ei keppi heilu aivan hulluna , ainakin ennen motonetistä saanu puslia muutamalla eurolla ja kuulemma marmoritiskiltäkään maksa kaikki kepin alapään hilut ku parikymppiä . On muuten huikea parannus vanhaan Volvoon pienellä rahalla eikä ole edes kovatöinen . Samalla säätää vaikka pakkilukonkin kohdilleen jos ei ole aivan kohallaan valmiiksi niin kyllä sitte pitäisi olla ihan hyvä tuntuma kepissä .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  FFG
# sentence:  Seurana toimii FFG turusta . Pitänee kai odottaa tammikuuhun , jolloin alkaa uusi tahinyrkleilyn peruskurssi .
# predicted:  ['neutral'] , original sentiment labels:  [['neutral', 0.5], ['negative', 0.5]]
# ------------------------------------------------------
# Target word:  Kings
# sentence:  Kings hävisi taktisesti , jotta pääsee ratkaisemaan mestaruuden kotikentällään .
# predicted:  ['positive'] , original sentiment labels:  [['positive', 0.5], ['neutral', 0.5]]
# ------------------------------------------------------
# Target word:  Greenpeace
# sentence:  Toki , mutta kuten sanoin Greenpeace aloitti täysin epäpoliittisena organisaationa luonnonsuojelun edistämiseksi , mutta nykyään se on täysin politisoitu ja se luonnonsuojelu on jäänyt taka-alalle .
# predicted:  positive , original sentiment labels:  ['mixed']
# ------------------------------------------------------

# %% [markdown]
# As we can see above, the model can determine one sentiment for the nondefinitive cases. In most cases, it coincides with one of the sentiments annotated originally to the sentence, but in some cases the model puts a different sentiment label on it. This happens, of course, especially if the original label was 'mixed' or 'unclear' as these labels were excluded from the model for being ambigous. But as the last row shows, there is room for improvement...
